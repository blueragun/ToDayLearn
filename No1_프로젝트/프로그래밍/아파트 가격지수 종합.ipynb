# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime

# %% [markdown]
# # 평수별 매매/전세/월세 지수 합본

# %% [markdown]
# ## 데이터 추가

# %% [markdown]
# ### 대형

# %%
LargeSize_deal = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 매매가격 지수/평수별/대형평수.xlsx')

# %%
LargeSize_charter = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 전세가격 지수/평수별/대형평수(전세).xlsx')

# %%
LargeSize_rent = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 월세가격 지수/평수별/대형평수(월세).xlsx')

# %% [markdown]
# ### 중형

# %%
MiddleSize_deal = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 매매가격 지수/평수별/중간평수.xlsx')

# %%
MiddleSize_charter = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 전세가격 지수/평수별/중형평수(전세).xlsx')

# %%
MiddleSize_rent = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 월세가격 지수/평수별/중형평수(월세).xlsx')

# %% [markdown]
# ### 소형

# %%
SmallSize_deal = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 매매가격 지수/평수별/소형평수.xlsx')

# %%
SmallSize_charter= pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 전세가격 지수/평수별/소형평수(전세).xlsx')

# %%
SmallSize_rent = pd.read_excel('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/규모별 아파트 월세가격 지수/평수별/소형평수(월세).xlsx')

# %% [markdown]
# ## 대형평수 가격지수 합본

# %%
pd.options.display.float_format = '{: .2f}'.format

# %% [markdown]
# ###대형매매

# %%
LargeSize_deal.drop(columns='Unnamed: 0', inplace=True)
LargeSize_deal.head(2)
# Out:
#       지역               규모  2012-01  2012-02  ...  2021-08  2021-09  2021-10  2021-11
# 0  서울특별시  102㎡초과 ~ 135㎡이하    87.68    87.28  ...   101.46   102.15   102.86   103.38
# 1   강북지역  102㎡초과 ~ 135㎡이하    92.25    91.98  ...   101.22   101.75   102.37   102.95
#
# [2 rows x 121 columns]

# %%
LargeSize_deal_group = LargeSize_deal.groupby(LargeSize_deal['지역']).mean()
LargeSize_deal_group
# Out:
#        2012-01  2012-02  2012-03  2012-04  ...  2021-08  2021-09  2021-10  2021-11
# 지역                                         ...
# 강남지역     88.39    87.83    87.25    86.44  ...   101.54   102.57   103.36   103.90
# 강북지역     95.14    94.99    94.63    94.39  ...   101.11   101.45   101.93   102.60
# 도심권      95.75    95.72    95.20    95.11  ...   101.23   101.90   102.74   103.51
# 동남권      86.63    85.85    85.28    84.54  ...   101.78   102.97   103.87   104.44
# 동북권      96.36    96.13    95.83    95.46  ...   101.08   101.38   101.62   102.01
# 서남권      92.43    92.33    91.61    90.81  ...   101.05   101.78   102.23   102.65
# 서북권      90.26    90.23    90.00    90.00  ...   100.76   100.92   101.68   103.06
# 서울특별시    90.63    90.17    89.66    88.98  ...   101.40   102.22   102.91   103.49
#
# [8 rows x 119 columns]

# %%
LargeSize_deal_group = LargeSize_deal_group.reset_index()
LargeSize_deal_group
# Out:
#       지역  2012-01  2012-02  2012-03  ...  2021-08  2021-09  2021-10  2021-11
# 0   강남지역    88.39    87.83    87.25  ...   101.54   102.57   103.36   103.90
# 1   강북지역    95.14    94.99    94.63  ...   101.11   101.45   101.93   102.60
# 2    도심권    95.75    95.72    95.20  ...   101.23   101.90   102.74   103.51
# 3    동남권    86.63    85.85    85.28  ...   101.78   102.97   103.87   104.44
# 4    동북권    96.36    96.13    95.83  ...   101.08   101.38   101.62   102.01
# 5    서남권    92.43    92.33    91.61  ...   101.05   101.78   102.23   102.65
# 6    서북권    90.26    90.23    90.00  ...   100.76   100.92   101.68   103.06
# 7  서울특별시    90.63    90.17    89.66  ...   101.40   102.22   102.91   103.49
#
# [8 rows x 120 columns]

# %%
LargeSize_deal_group.rename(columns = {'지역':'구분'}, inplace=True)
LargeSize_deal_group
# Out:
#       구분  2012-01  2012-02  2012-03  ...  2021-08  2021-09  2021-10  2021-11
# 0   강남지역    88.39    87.83    87.25  ...   101.54   102.57   103.36   103.90
# 1   강북지역    95.14    94.99    94.63  ...   101.11   101.45   101.93   102.60
# 2    도심권    95.75    95.72    95.20  ...   101.23   101.90   102.74   103.51
# 3    동남권    86.63    85.85    85.28  ...   101.78   102.97   103.87   104.44
# 4    동북권    96.36    96.13    95.83  ...   101.08   101.38   101.62   102.01
# 5    서남권    92.43    92.33    91.61  ...   101.05   101.78   102.23   102.65
# 6    서북권    90.26    90.23    90.00  ...   100.76   100.92   101.68   103.06
# 7  서울특별시    90.63    90.17    89.66  ...   101.40   102.22   102.91   103.49
#
# [8 rows x 120 columns]

# %% [markdown]
# #### 해야할 것
# 1. 인덱스 수 추가
# 2. 컬럼-구분-매매 추가  / 인덱스[1] 매매 삭제
# 3. 각 공통시 묶기(대형/중형/소형, 유형별은 별도)
# 3. 크기별 매매/전세/월세 묶기 → 종합 묶기??

# %% [markdown]
# #### 컬럼-열 바꾸기

# %%
LargeSize_deal_group = LargeSize_deal_group.transpose()
LargeSize_deal_group
# Out:
#               0       1       2       3       4       5       6       7
# 구분         강남지역    강북지역     도심권     동남권     동북권     서남권     서북권   서울특별시
# 2012-01   88.39   95.14   95.75   86.63   96.36   92.43   90.26   90.63
# 2012-02   87.83   94.99   95.72   85.85   96.13   92.33   90.23   90.17
# 2012-03   87.25   94.63   95.20   85.28   95.83   91.61   90.00   89.66
# 2012-04   86.44   94.39   95.11   84.54   95.46   90.81   90.00   88.98
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.83  100.60  100.56  100.92  100.53  100.66  100.61  100.75
# 2021-08  101.54  101.11  101.23  101.78  101.08  101.05  100.76  101.40
# 2021-09  102.57  101.45  101.90  102.97  101.38  101.78  100.92  102.22
# 2021-10  103.36  101.93  102.74  103.87  101.62  102.23  101.68  102.91
# 2021-11  103.90  102.60  103.51  104.44  102.01  102.65  103.06  103.49
#
# [120 rows x 8 columns]

# %% [markdown]
# #### 0번 행 지우기

# %%
LargeSize_deal_group.rename(columns=LargeSize_deal_group.iloc[0], inplace=True)
LargeSize_deal_group = LargeSize_deal_group.drop(LargeSize_deal_group.index[0])
LargeSize_deal_group
# Out:
#            강남지역    강북지역     도심권     동남권     동북권     서남권     서북권   서울특별시
# 2012-01   88.39   95.14   95.75   86.63   96.36   92.43   90.26   90.63
# 2012-02   87.83   94.99   95.72   85.85   96.13   92.33   90.23   90.17
# 2012-03   87.25   94.63   95.20   85.28   95.83   91.61   90.00   89.66
# 2012-04   86.44   94.39   95.11   84.54   95.46   90.81   90.00   88.98
# 2012-05   85.90   94.17   94.97   84.04   95.15   90.24   89.89   88.53
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.83  100.60  100.56  100.92  100.53  100.66  100.61  100.75
# 2021-08  101.54  101.11  101.23  101.78  101.08  101.05  100.76  101.40
# 2021-09  102.57  101.45  101.90  102.97  101.38  101.78  100.92  102.22
# 2021-10  103.36  101.93  102.74  103.87  101.62  102.23  101.68  102.91
# 2021-11  103.90  102.60  103.51  104.44  102.01  102.65  103.06  103.49
#
# [119 rows x 8 columns]

# %% [markdown]
# #### 인덱스 초기화

# %%
LargeSize_deal_group = LargeSize_deal_group.reset_index()
LargeSize_deal_group
# Out:
#        index    강남지역    강북지역     도심권     동남권     동북권     서남권     서북권   서울특별시
# 0    2012-01   88.39   95.14   95.75   86.63   96.36   92.43   90.26   90.63
# 1    2012-02   87.83   94.99   95.72   85.85   96.13   92.33   90.23   90.17
# 2    2012-03   87.25   94.63   95.20   85.28   95.83   91.61   90.00   89.66
# 3    2012-04   86.44   94.39   95.11   84.54   95.46   90.81   90.00   88.98
# 4    2012-05   85.90   94.17   94.97   84.04   95.15   90.24   89.89   88.53
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 114  2021-07  100.83  100.60  100.56  100.92  100.53  100.66  100.61  100.75
# 115  2021-08  101.54  101.11  101.23  101.78  101.08  101.05  100.76  101.40
# 116  2021-09  102.57  101.45  101.90  102.97  101.38  101.78  100.92  102.22
# 117  2021-10  103.36  101.93  102.74  103.87  101.62  102.23  101.68  102.91
# 118  2021-11  103.90  102.60  103.51  104.44  102.01  102.65  103.06  103.49
#
# [119 rows x 9 columns]

# %% [markdown]
# #### 컬럼 이름 변경

# %%
LargeSize_deal_group.rename(columns = {'index':'날짜'}, inplace=True)
LargeSize_deal_group
# Out:
#           날짜    강남지역    강북지역     도심권     동남권     동북권     서남권     서북권   서울특별시
# 0    2012-01   88.39   95.14   95.75   86.63   96.36   92.43   90.26   90.63
# 1    2012-02   87.83   94.99   95.72   85.85   96.13   92.33   90.23   90.17
# 2    2012-03   87.25   94.63   95.20   85.28   95.83   91.61   90.00   89.66
# 3    2012-04   86.44   94.39   95.11   84.54   95.46   90.81   90.00   88.98
# 4    2012-05   85.90   94.17   94.97   84.04   95.15   90.24   89.89   88.53
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 114  2021-07  100.83  100.60  100.56  100.92  100.53  100.66  100.61  100.75
# 115  2021-08  101.54  101.11  101.23  101.78  101.08  101.05  100.76  101.40
# 116  2021-09  102.57  101.45  101.90  102.97  101.38  101.78  100.92  102.22
# 117  2021-10  103.36  101.93  102.74  103.87  101.62  102.23  101.68  102.91
# 118  2021-11  103.90  102.60  103.51  104.44  102.01  102.65  103.06  103.49
#
# [119 rows x 9 columns]

# %% [markdown]
# #### 컬럼 추가

# %%
LargeSize_deal_group.insert(1, '크기', '대형') 
LargeSize_deal_group.insert(1, '구분', '매매') 
LargeSize_deal_group
# Out:
#           날짜  구분  크기    강남지역    강북지역  ...     동남권     동북권     서남권     서북권   서울특별시
# 0    2012-01  매매  대형   88.39   95.14  ...   86.63   96.36   92.43   90.26   90.63
# 1    2012-02  매매  대형   87.83   94.99  ...   85.85   96.13   92.33   90.23   90.17
# 2    2012-03  매매  대형   87.25   94.63  ...   85.28   95.83   91.61   90.00   89.66
# 3    2012-04  매매  대형   86.44   94.39  ...   84.54   95.46   90.81   90.00   88.98
# 4    2012-05  매매  대형   85.90   94.17  ...   84.04   95.15   90.24   89.89   88.53
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  매매  대형  100.83  100.60  ...  100.92  100.53  100.66  100.61  100.75
# 115  2021-08  매매  대형  101.54  101.11  ...  101.78  101.08  101.05  100.76  101.40
# 116  2021-09  매매  대형  102.57  101.45  ...  102.97  101.38  101.78  100.92  102.22
# 117  2021-10  매매  대형  103.36  101.93  ...  103.87  101.62  102.23  101.68  102.91
# ...

# %% [markdown]
# #### 순서변경

# %%
LargeSize_deal_group = LargeSize_deal_group[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
LargeSize_deal_group
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  대형   90.63   95.75  ...   96.36   90.26   88.39   86.63   92.43
# 1    2012-02  매매  대형   90.17   95.72  ...   96.13   90.23   87.83   85.85   92.33
# 2    2012-03  매매  대형   89.66   95.20  ...   95.83   90.00   87.25   85.28   91.61
# 3    2012-04  매매  대형   88.98   95.11  ...   95.46   90.00   86.44   84.54   90.81
# 4    2012-05  매매  대형   88.53   94.97  ...   95.15   89.89   85.90   84.04   90.24
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  매매  대형  100.75  100.56  ...  100.53  100.61  100.83  100.92  100.66
# 115  2021-08  매매  대형  101.40  101.23  ...  101.08  100.76  101.54  101.78  101.05
# 116  2021-09  매매  대형  102.22  101.90  ...  101.38  100.92  102.57  102.97  101.78
# 117  2021-10  매매  대형  102.91  102.74  ...  101.62  101.68  103.36  103.87  102.23
# ...

# %%
LargeSize_charter.drop(columns='Unnamed: 0', inplace=True)
LargeSize_charter.head(2)
# Out:
#       지역               규모  2012-01  2012-02  ...  2021-08  2021-09  2021-10  2021-11
# 0  서울특별시  102㎡초과 ~ 135㎡이하    72.52    72.43  ...   101.27   101.84   102.47   103.07
# 1   강북지역  102㎡초과 ~ 135㎡이하    74.05    74.13  ...   100.98   101.48   102.16   102.80
#
# [2 rows x 121 columns]

# %%
LargeSize_charter_group = LargeSize_charter.groupby(LargeSize_rent['지역']).mean()
LargeSize_charter_group = LargeSize_charter_group.reset_index()
LargeSize_charter_group.rename(columns = {'지역':'구분'}, inplace=True)
LargeSize_charter_group = LargeSize_charter_group.transpose()
LargeSize_charter_group.rename(columns=LargeSize_charter_group.iloc[0], inplace=True)
LargeSize_charter_group = LargeSize_charter_group.drop(LargeSize_charter_group.index[0])
LargeSize_charter_group = LargeSize_charter_group.reset_index()
LargeSize_charter_group.rename(columns = {'index':'날짜'}, inplace=True)
LargeSize_charter_group.insert(1, '크기', '대형') 
LargeSize_charter_group.insert(1, '구분', '전세') 
LargeSize_charter_group = LargeSize_charter_group[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
LargeSize_charter_group
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  전세  대형   74.16   79.66  ...   75.55   78.88   72.95   75.07   70.94
# 1    2012-02  전세  대형   74.07   79.66  ...   75.61   78.17   72.82   74.96   70.81
# 2    2012-03  전세  대형   73.88   79.28  ...   75.35   77.91   72.66   74.71   70.78
# 3    2012-04  전세  대형   73.50   79.28  ...   75.28   77.97   72.20   74.01   70.73
# 4    2012-05  전세  대형   73.18   79.19  ...   75.15   77.85   71.78   73.48   70.45
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  전세  대형  100.81  100.44  ...  100.54  100.49  100.97  101.06  100.91
# 115  2021-08  전세  대형  101.33  101.03  ...  100.91  101.08  101.51  101.54  101.48
# 116  2021-09  전세  대형  101.81  101.54  ...  101.39  101.60  102.01  101.97  101.99
# 117  2021-10  전세  대형  102.29  101.97  ...  101.90  101.85  102.51  102.47  102.49
# ...

# %%
LargeSize_rent.drop(columns='Unnamed: 0', inplace=True)
LargeSize_rent.head(2)
# Out:
#       지역               규모  2015-06  2015-07  ...  2021-08  2021-09  2021-10  2021-11
# 0  서울특별시  102㎡초과 ~ 135㎡이하    98.94    98.99  ...   100.28   100.67   101.08   101.32
# 1   강북지역  102㎡초과 ~ 135㎡이하    99.06    99.08  ...   100.13   100.40   100.78   101.16
#
# [2 rows x 80 columns]

# %%
LargeSize_rent_group = LargeSize_rent.groupby(LargeSize_rent['지역']).mean()
LargeSize_rent_group
# Out:
#        2015-06  2015-07  2015-08  2015-09  ...  2021-08  2021-09  2021-10  2021-11
# 지역                                         ...
# 강남지역     98.33    98.38    98.49    98.62  ...   100.33   100.77   101.09   101.25
# 강북지역     98.67    98.73    98.70    98.67  ...   100.41   100.64   100.92   101.09
# 도심권      98.35    98.30    98.23    98.22  ...   100.13   100.25   100.53   100.70
# 동남권      98.19    98.23    98.39    98.59  ...   100.47   101.05   101.36   101.61
# 동북권      98.74    98.95    99.08    99.14  ...   100.33   100.56   100.92   100.72
# 서남권      99.06    99.15    99.14    99.15  ...    99.97   100.21   100.64   100.49
# 서북권      99.57    99.53    99.32    99.03  ...   100.76   101.16   101.33   102.09
# 서울특별시    98.43    98.49    98.55    98.63  ...   100.33   100.70   101.01   101.18
#
# [8 rows x 78 columns]

# %%
LargeSize_rent_group = LargeSize_rent_group.reset_index()
LargeSize_rent_group.rename(columns = {'지역':'구분'}, inplace=True)
LargeSize_rent_group = LargeSize_rent_group.transpose()
LargeSize_rent_group.rename(columns=LargeSize_rent_group.iloc[0], inplace=True)
LargeSize_rent_group = LargeSize_rent_group.drop(LargeSize_rent_group.index[0])
LargeSize_rent_group = LargeSize_rent_group.reset_index()
LargeSize_rent_group.rename(columns = {'index':'날짜'}, inplace=True)
LargeSize_rent_group.insert(1, '크기', '대형')
LargeSize_rent_group.insert(1, '구분', '월세') 
LargeSize_rent_group = LargeSize_rent_group[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
LargeSize_rent_group
# Out:
#          날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0   2015-06  월세  대형   98.43   98.35  ...   98.74   99.57   98.33   98.19   99.06
# 1   2015-07  월세  대형   98.49   98.30  ...   98.95   99.53   98.38   98.23   99.15
# 2   2015-08  월세  대형   98.55   98.23  ...   99.08   99.32   98.49   98.39   99.14
# 3   2015-09  월세  대형   98.63   98.22  ...   99.14   99.03   98.62   98.59   99.15
# 4   2015-10  월세  대형   98.69   98.21  ...   99.22   98.61   98.71   98.71   99.18
# ..      ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 73  2021-07  월세  대형  100.19  100.07  ...  100.07  100.16  100.24  100.28  100.21
# 74  2021-08  월세  대형  100.33  100.13  ...  100.33  100.76  100.33  100.47   99.97
# 75  2021-09  월세  대형  100.70  100.25  ...  100.56  101.16  100.77  101.05  100.21
# 76  2021-10  월세  대형  101.01  100.53  ...  100.92  101.33  101.09  101.36  100.64
# 77  2021-11  월세  대형  101.18  100.70  ...  100.72  102.09  101.25  101.61  100.49
#
# ...

# %% [markdown]
# ## 대형 합본
# - 규모별 평균값

# %%
LargeSize_deal_group.head(2)
# Out:
#         날짜  구분  크기  서울특별시    도심권   강북지역    동북권    서북권   강남지역    동남권    서남권
# 0  2012-01  매매  대형  90.63  95.75  95.14  96.36  90.26  88.39  86.63  92.43
# 1  2012-02  매매  대형  90.17  95.72  94.99  96.13  90.23  87.83  85.85  92.33

# %%
LargeSize_charter_group.head(2)
# Out:
#         날짜  구분  크기  서울특별시    도심권   강북지역    동북권    서북권   강남지역    동남권    서남권
# 0  2012-01  전세  대형  74.16  79.66  77.14  75.55  78.88  72.95  75.07  70.94
# 1  2012-02  전세  대형  74.07  79.66  77.05  75.61  78.17  72.82  74.96  70.81

# %%
LargeSize_rent_group.head(2)
# Out:
#         날짜  구분  크기  서울특별시    도심권   강북지역    동북권    서북권   강남지역    동남권    서남권
# 0  2015-06  월세  대형  98.43  98.35  98.67  98.74  99.57  98.33  98.19  99.06
# 1  2015-07  월세  대형  98.49  98.30  98.73  98.95  99.53  98.38  98.23  99.15

# %%
LargeSize = pd.merge(left=LargeSize_deal_group, right=LargeSize_charter_group, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
LargeSize
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  대형   90.63   95.75  ...   96.36   90.26   88.39   86.63   92.43
# 1    2012-02  매매  대형   90.17   95.72  ...   96.13   90.23   87.83   85.85   92.33
# 2    2012-03  매매  대형   89.66   95.20  ...   95.83   90.00   87.25   85.28   91.61
# 3    2012-04  매매  대형   88.98   95.11  ...   95.46   90.00   86.44   84.54   90.81
# 4    2012-05  매매  대형   88.53   94.97  ...   95.15   89.89   85.90   84.04   90.24
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 233  2021-07  전세  대형  100.81  100.44  ...  100.54  100.49  100.97  101.06  100.91
# 234  2021-08  전세  대형  101.33  101.03  ...  100.91  101.08  101.51  101.54  101.48
# 235  2021-09  전세  대형  101.81  101.54  ...  101.39  101.60  102.01  101.97  101.99
# 236  2021-10  전세  대형  102.29  101.97  ...  101.90  101.85  102.51  102.47  102.49
# ...

# %%
LargeSize = LargeSize.sort_values(by='날짜')
LargeSize.head()
# Out:
#           날짜  구분  크기  서울특별시    도심권   강북지역    동북권    서북권   강남지역    동남권    서남권
# 0    2012-01  매매  대형  90.63  95.75  95.14  96.36  90.26  88.39  86.63  92.43
# 119  2012-01  전세  대형  74.16  79.66  77.14  75.55  78.88  72.95  75.07  70.94
# 1    2012-02  매매  대형  90.17  95.72  94.99  96.13  90.23  87.83  85.85  92.33
# 120  2012-02  전세  대형  74.07  79.66  77.05  75.61  78.17  72.82  74.96  70.81
# 2    2012-03  매매  대형  89.66  95.20  94.63  95.83  90.00  87.25  85.28  91.61

# %%
LargeSize = LargeSize.reset_index()
LargeSize.head()
# Out:
#    index       날짜  구분  크기  서울특별시  ...    동북권    서북권   강남지역    동남권    서남권
# 0      0  2012-01  매매  대형  90.63  ...  96.36  90.26  88.39  86.63  92.43
# 1    119  2012-01  전세  대형  74.16  ...  75.55  78.88  72.95  75.07  70.94
# 2      1  2012-02  매매  대형  90.17  ...  96.13  90.23  87.83  85.85  92.33
# 3    120  2012-02  전세  대형  74.07  ...  75.61  78.17  72.82  74.96  70.81
# 4      2  2012-03  매매  대형  89.66  ...  95.83  90.00  87.25  85.28  91.61
#
# [5 rows x 12 columns]

# %%
LargeSize.drop(columns='index', inplace=True)
LargeSize
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  대형   90.63   95.75  ...   96.36   90.26   88.39   86.63   92.43
# 1    2012-01  전세  대형   74.16   79.66  ...   75.55   78.88   72.95   75.07   70.94
# 2    2012-02  매매  대형   90.17   95.72  ...   96.13   90.23   87.83   85.85   92.33
# 3    2012-02  전세  대형   74.07   79.66  ...   75.61   78.17   72.82   74.96   70.81
# 4    2012-03  매매  대형   89.66   95.20  ...   95.83   90.00   87.25   85.28   91.61
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 233  2021-09  매매  대형  102.22  101.90  ...  101.38  100.92  102.57  102.97  101.78
# 234  2021-10  전세  대형  102.29  101.97  ...  101.90  101.85  102.51  102.47  102.49
# 235  2021-10  매매  대형  102.91  102.74  ...  101.62  101.68  103.36  103.87  102.23
# 236  2021-11  매매  대형  103.49  103.51  ...  102.01  103.06  103.90  104.44  102.65
# ...

# %%
LargeSize = pd.merge(left=LargeSize, right=LargeSize_rent_group, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
LargeSize
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  대형   90.63   95.75  ...   96.36   90.26   88.39   86.63   92.43
# 1    2012-01  전세  대형   74.16   79.66  ...   75.55   78.88   72.95   75.07   70.94
# 2    2012-02  매매  대형   90.17   95.72  ...   96.13   90.23   87.83   85.85   92.33
# 3    2012-02  전세  대형   74.07   79.66  ...   75.61   78.17   72.82   74.96   70.81
# 4    2012-03  매매  대형   89.66   95.20  ...   95.83   90.00   87.25   85.28   91.61
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 311  2021-07  월세  대형  100.19  100.07  ...  100.07  100.16  100.24  100.28  100.21
# 312  2021-08  월세  대형  100.33  100.13  ...  100.33  100.76  100.33  100.47   99.97
# 313  2021-09  월세  대형  100.70  100.25  ...  100.56  101.16  100.77  101.05  100.21
# 314  2021-10  월세  대형  101.01  100.53  ...  100.92  101.33  101.09  101.36  100.64
# ...

# %%
LargeSize = LargeSize.sort_values(by='날짜')
LargeSize = LargeSize.reset_index()
LargeSize.drop(columns='index', inplace=True)
LargeSize
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  대형   90.63   95.75  ...   96.36   90.26   88.39   86.63   92.43
# 1    2012-01  전세  대형   74.16   79.66  ...   75.55   78.88   72.95   75.07   70.94
# 2    2012-02  매매  대형   90.17   95.72  ...   96.13   90.23   87.83   85.85   92.33
# 3    2012-02  전세  대형   74.07   79.66  ...   75.61   78.17   72.82   74.96   70.81
# 4    2012-03  매매  대형   89.66   95.20  ...   95.83   90.00   87.25   85.28   91.61
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 311  2021-10  매매  대형  102.91  102.74  ...  101.62  101.68  103.36  103.87  102.23
# 312  2021-10  월세  대형  101.01  100.53  ...  100.92  101.33  101.09  101.36  100.64
# 313  2021-11  매매  대형  103.49  103.51  ...  102.01  103.06  103.90  104.44  102.65
# 314  2021-11  전세  대형  102.71  102.63  ...  102.44  102.54  102.88  102.99  102.63
# ...

# %%
LargeSize.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/대형 가격지수(총합).csv')

# %% [markdown]
# ### 중형 매매/전세/월세

# %%
MiddleSize_deal.head()
# Out:
#    Unnamed: 0     지역             규모  ...  2021-09  2021-10  2021-11
# 0           0  서울특별시  60㎡초과 ~ 85㎡이하  ...   102.54   103.38   104.02
# 1           1   강북지역  60㎡초과 ~ 85㎡이하  ...   102.28   103.04   103.57
# 2           2    도심권  60㎡초과 ~ 85㎡이하  ...   102.55   103.73   104.65
# 3           3    동북권  60㎡초과 ~ 85㎡이하  ...   102.26   102.87   103.27
# 4           4    서북권  60㎡초과 ~ 85㎡이하  ...   102.24   103.37   104.13
#
# [5 rows x 122 columns]

# %%
MiddleSize_deal.drop(columns='Unnamed: 0', inplace=True)

# %%
MiddleSize_deal_group = MiddleSize_deal.groupby(MiddleSize_deal['지역']).mean()
MiddleSize_deal_group
# Out:
#        2012-01  2012-02  2012-03  2012-04  ...  2021-08  2021-09  2021-10  2021-11
# 지역                                         ...
# 강남지역     77.05    76.75    76.37    75.82  ...   101.80   102.81   103.55   104.30
# 강북지역     83.79    83.72    83.64    83.21  ...   101.42   102.23   102.96   103.44
# 도심권      87.46    87.36    86.95    86.79  ...   101.09   101.89   103.06   104.27
# 동남권      75.14    74.63    74.07    73.58  ...   102.11   103.41   104.38   105.40
# 동북권      82.90    82.86    82.85    82.24  ...   101.58   102.48   103.04   103.30
# 서남권      79.24    79.16    78.97    78.30  ...   101.47   102.17   102.71   103.20
# 서북권      84.25    84.08    83.99    83.94  ...   101.22   101.90   102.86   103.47
# 서울특별시    79.55    79.33    79.06    78.55  ...   101.66   102.58   103.31   103.95
#
# [8 rows x 119 columns]

# %%
MiddleSize_deal_group = MiddleSize_deal_group.reset_index()

# %%
MiddleSize_deal_group.rename(columns = {'지역':'구분'}, inplace=True)

# %%
MiddleSize_deal_group = MiddleSize_deal_group.transpose()

# %%
MiddleSize_deal_group.rename(columns=MiddleSize_deal_group.iloc[0], inplace=True)
MiddleSize_deal_group = MiddleSize_deal_group.drop(MiddleSize_deal_group.index[0])

# %%
MiddleSize_deal_group = MiddleSize_deal_group.reset_index()

# %%
MiddleSize_deal_group.rename(columns = {'index':'날짜'}, inplace=True)
MiddleSize_deal_group.insert(1, '크기', '중형')
MiddleSize_deal_group.insert(1, '구분', '매매')

# %%
MiddleSize_deal_group
# Out:
#           날짜  구분  크기    강남지역    강북지역  ...     동남권     동북권     서남권     서북권   서울특별시
# 0    2012-01  매매  중형   77.05   83.79  ...   75.14   82.90   79.24   84.25   79.55
# 1    2012-02  매매  중형   76.75   83.72  ...   74.63   82.86   79.16   84.08   79.33
# 2    2012-03  매매  중형   76.37   83.64  ...   74.07   82.85   78.97   83.99   79.06
# 3    2012-04  매매  중형   75.82   83.21  ...   73.58   82.24   78.30   83.94   78.55
# 4    2012-05  매매  중형   75.38   82.67  ...   73.18   81.54   77.82   83.60   78.09
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  매매  중형  100.93  100.68  ...  101.06  100.85  100.79  100.51  100.84
# 115  2021-08  매매  중형  101.80  101.42  ...  102.11  101.58  101.47  101.22  101.66
# 116  2021-09  매매  중형  102.81  102.23  ...  103.41  102.48  102.17  101.90  102.58
# 117  2021-10  매매  중형  103.55  102.96  ...  104.38  103.04  102.71  102.86  103.31
# ...

# %%
MiddleSize_deal_group = MiddleSize_deal_group[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
MiddleSize_deal_group
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  중형   79.55   87.46  ...   82.90   84.25   77.05   75.14   79.24
# 1    2012-02  매매  중형   79.33   87.36  ...   82.86   84.08   76.75   74.63   79.16
# 2    2012-03  매매  중형   79.06   86.95  ...   82.85   83.99   76.37   74.07   78.97
# 3    2012-04  매매  중형   78.55   86.79  ...   82.24   83.94   75.82   73.58   78.30
# 4    2012-05  매매  중형   78.09   86.71  ...   81.54   83.60   75.38   73.18   77.82
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  매매  중형  100.84  100.26  ...  100.85  100.51  100.93  101.06  100.79
# 115  2021-08  매매  중형  101.66  101.09  ...  101.58  101.22  101.80  102.11  101.47
# 116  2021-09  매매  중형  102.58  101.89  ...  102.48  101.90  102.81  103.41  102.17
# 117  2021-10  매매  중형  103.31  103.06  ...  103.04  102.86  103.55  104.38  102.71
# ...

# %%
MiddleSize_charter.drop(columns='Unnamed: 0', inplace=True)
MiddleSize_charter_group = MiddleSize_charter.groupby(MiddleSize_charter['지역']).mean()
MiddleSize_charter_group = MiddleSize_charter_group.reset_index()
MiddleSize_charter_group.rename(columns = {'지역':'구분'}, inplace=True)
MiddleSize_charter_group = MiddleSize_charter_group.transpose()
MiddleSize_charter_group.rename(columns=MiddleSize_charter_group.iloc[0], inplace=True)
MiddleSize_charter_group = MiddleSize_charter_group.drop(MiddleSize_charter_group.index[0])
MiddleSize_charter_group = MiddleSize_charter_group.reset_index()
MiddleSize_charter_group.rename(columns = {'index':'날짜'}, inplace=True)
MiddleSize_charter_group.insert(1, '크기', '중형') 
MiddleSize_charter_group.insert(1, '구분', '전세')
MiddleSize_charter_group = MiddleSize_charter_group[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
MiddleSize_charter_group
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  전세  중형   70.02   69.94  ...   71.31   72.66   69.03   71.03   66.42
# 1    2012-02  전세  중형   70.08   69.94  ...   71.50   72.93   69.02   70.92   66.46
# 2    2012-03  전세  중형   70.06   70.22  ...   71.73   73.04   68.89   70.73   66.32
# 3    2012-04  전세  중형   69.70   70.26  ...   71.20   73.14   68.50   70.35   65.91
# 4    2012-05  전세  중형   69.57   70.25  ...   70.92   73.07   68.40   70.25   65.78
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  전세  중형  100.67  100.68  ...  100.35  100.55  100.80  100.85  100.76
# 115  2021-08  전세  중형  101.41  101.46  ...  101.08  100.93  101.59  101.67  101.53
# 116  2021-09  전세  중형  102.07  102.27  ...  102.09  101.38  102.14  102.33  101.95
# 117  2021-10  전세  중형  102.67  103.37  ...  102.45  101.87  102.81  102.95  102.67
# ...

# %%
MiddleSize_rent.drop(columns='Unnamed: 0', inplace=True)
MiddleSize_rent_group = MiddleSize_rent.groupby(MiddleSize_rent['지역']).mean()
MiddleSize_rent_group = MiddleSize_rent_group.reset_index()
MiddleSize_rent_group.rename(columns = {'지역':'구분'}, inplace=True)
MiddleSize_rent_group = MiddleSize_rent_group.transpose()
MiddleSize_rent_group.rename(columns=MiddleSize_rent_group.iloc[0], inplace=True)
MiddleSize_rent_group = MiddleSize_rent_group.drop(MiddleSize_rent_group.index[0])
MiddleSize_rent_group = MiddleSize_rent_group.reset_index()
MiddleSize_rent_group.rename(columns = {'index':'날짜'}, inplace=True)
MiddleSize_rent_group.insert(1, '크기', '중형') 
MiddleSize_rent_group.insert(1, '구분', '월세') 
MiddleSize_rent_group = MiddleSize_rent_group[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
MiddleSize_rent_group
# Out:
#          날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0   2015-06  월세  중형   98.97   98.26  ...   98.29   98.84   99.18   99.49   98.80
# 1   2015-07  월세  중형   98.96   98.11  ...   98.31   98.71   99.18   99.54   98.72
# 2   2015-08  월세  중형   99.04   97.87  ...   98.46   98.65   99.27   99.67   98.77
# 3   2015-09  월세  중형   99.28   97.84  ...   98.75   98.56   99.57  100.20   98.79
# 4   2015-10  월세  중형   99.43   97.83  ...   99.30   98.48   99.65  100.32   98.84
# ..      ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 73  2021-07  월세  중형  100.14  100.06  ...   99.97  100.11  100.22  100.31  100.13
# 74  2021-08  월세  중형  100.12  100.66  ...   99.46  100.43  100.26  100.34  100.24
# 75  2021-09  월세  중형  100.29  100.88  ...   99.47  100.67  100.48  100.61  100.44
# 76  2021-10  월세  중형  100.54  101.12  ...   99.70  100.84  100.74  101.01  100.59
# 77  2021-11  월세  중형  100.94  101.54  ...  100.44  101.49  101.02  101.47  100.69
#
# ...

# %% [markdown]
# ##중형 합본

# %%
MiddleSize = pd.merge(left=MiddleSize_deal_group, right=MiddleSize_charter_group, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
MiddleSize = MiddleSize.sort_values(by='날짜')
MiddleSize = MiddleSize.reset_index()
MiddleSize.drop(columns='index', inplace=True)
MiddleSize = pd.merge(left=MiddleSize, right=MiddleSize_rent_group, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
MiddleSize = MiddleSize.sort_values(by='날짜')
MiddleSize = MiddleSize.reset_index()
MiddleSize.drop(columns='index', inplace=True)
MiddleSize
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  중형   79.55   87.46  ...   82.90   84.25   77.05   75.14   79.24
# 1    2012-01  전세  중형   70.02   69.94  ...   71.31   72.66   69.03   71.03   66.42
# 2    2012-02  매매  중형   79.33   87.36  ...   82.86   84.08   76.75   74.63   79.16
# 3    2012-02  전세  중형   70.08   69.94  ...   71.50   72.93   69.02   70.92   66.46
# 4    2012-03  매매  중형   79.06   86.95  ...   82.85   83.99   76.37   74.07   78.97
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 311  2021-10  매매  중형  103.31  103.06  ...  103.04  102.86  103.55  104.38  102.71
# 312  2021-10  월세  중형  100.54  101.12  ...   99.70  100.84  100.74  101.01  100.59
# 313  2021-11  매매  중형  103.95  104.27  ...  103.30  103.47  104.30  105.40  103.20
# 314  2021-11  전세  중형  103.11  103.73  ...  103.11  102.21  103.21  103.28  103.13
# ...

# %%
MiddleSize.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/중형 가격지수(총합).csv')

# %% [markdown]
# ###소형 매매/전세/월세

# %%
SmallSize_deal.drop(columns='Unnamed: 0', inplace=True)

# %% [markdown]
# #### 초소형/소형 나누기
# - 사유 : 평균값 산출시 40㎡이하가 NaN이기에 산출이 안됨
# # - 40㎡이하 분리, 재병합

# %%
SSize_1 = SmallSize_deal['규모'] == '40㎡이하'
SSize_1 = SmallSize_deal[SSize_1]
SSize_1
# Out:
#       지역     규모 2012-01 2012-02  ... 2021-08 2021-09 2021-10 2021-11
# 0  서울특별시  40㎡이하       -       -  ...  101.77  102.69  103.63  104.34
# 1   강북지역  40㎡이하       -       -  ...  102.06  102.96  103.83  104.41
# 2    도심권  40㎡이하       -       -  ...  101.18  101.33  101.80  102.11
# 3    동북권  40㎡이하       -       -  ...  102.43  103.71  104.82  105.50
# 4    서북권  40㎡이하       -       -  ...  101.19  101.10  101.36  101.72
# 5   강남지역  40㎡이하       -       -  ...  101.55  102.47  103.47  104.27
# 6    서남권  40㎡이하       -       -  ...  101.28  102.13  103.09  103.60
# 7    동남권  40㎡이하       -       -  ...  101.87  102.89  103.93  105.09
#
# [8 rows x 121 columns]

# %%
SSize_2 = SmallSize_deal['규모'] == '40㎡초과 ~ 60㎡이하'
SSize_2 = SmallSize_deal[SSize_2]
SSize_2
# Out:
#        지역             규모 2012-01 2012-02  ... 2021-08 2021-09 2021-10 2021-11
# 8   서울특별시  40㎡초과 ~ 60㎡이하   71.83   71.74  ...  102.15  103.20  104.17  104.79
# 9    강북지역  40㎡초과 ~ 60㎡이하   73.37   73.32  ...  102.39  103.41  104.28  104.85
# 10    도심권  40㎡초과 ~ 60㎡이하   72.52   72.42  ...  101.37  102.35  103.86  105.28
# 11    동북권  40㎡초과 ~ 60㎡이하   74.22   74.22  ...  102.63  103.63  104.36  104.85
# 12    서북권  40㎡초과 ~ 60㎡이하   69.78   69.55  ...  101.73  102.88  104.09  104.73
# 13   강남지역  40㎡초과 ~ 60㎡이하   70.14   70.02  ...  101.86  102.94  104.04  104.71
# 14    서남권  40㎡초과 ~ 60㎡이하   72.08   72.08  ...  101.74  102.93  103.85  104.41
# 15    동남권  40㎡초과 ~ 60㎡이하   67.35   67.09  ...  102.05  102.97  104.34  105.20
#
# [8 rows x 121 columns]

# %%
SSize_1 = SSize_1.reset_index()
SSize_1.rename(columns = {'지역':'구분'}, inplace=True)
SSize_1
# Out:
#    index     구분     규모 2012-01  ... 2021-08 2021-09 2021-10 2021-11
# 0      0  서울특별시  40㎡이하       -  ...  101.77  102.69  103.63  104.34
# 1      1   강북지역  40㎡이하       -  ...  102.06  102.96  103.83  104.41
# 2      2    도심권  40㎡이하       -  ...  101.18  101.33  101.80  102.11
# 3      3    동북권  40㎡이하       -  ...  102.43  103.71  104.82  105.50
# 4      4    서북권  40㎡이하       -  ...  101.19  101.10  101.36  101.72
# 5      5   강남지역  40㎡이하       -  ...  101.55  102.47  103.47  104.27
# 6      6    서남권  40㎡이하       -  ...  101.28  102.13  103.09  103.60
# 7      7    동남권  40㎡이하       -  ...  101.87  102.89  103.93  105.09
#
# [8 rows x 122 columns]

# %%
SSize_1.drop(columns='index', inplace=True)
SSize_1
# Out:
#       구분     규모 2012-01 2012-02  ... 2021-08 2021-09 2021-10 2021-11
# 0  서울특별시  40㎡이하       -       -  ...  101.77  102.69  103.63  104.34
# 1   강북지역  40㎡이하       -       -  ...  102.06  102.96  103.83  104.41
# 2    도심권  40㎡이하       -       -  ...  101.18  101.33  101.80  102.11
# 3    동북권  40㎡이하       -       -  ...  102.43  103.71  104.82  105.50
# 4    서북권  40㎡이하       -       -  ...  101.19  101.10  101.36  101.72
# 5   강남지역  40㎡이하       -       -  ...  101.55  102.47  103.47  104.27
# 6    서남권  40㎡이하       -       -  ...  101.28  102.13  103.09  103.60
# 7    동남권  40㎡이하       -       -  ...  101.87  102.89  103.93  105.09
#
# [8 rows x 121 columns]

# %%
SSize_1.drop(columns='규모', inplace=True)
SSize_1
# Out:
#       구분 2012-01 2012-02 2012-03  ... 2021-08 2021-09 2021-10 2021-11
# 0  서울특별시       -       -       -  ...  101.77  102.69  103.63  104.34
# 1   강북지역       -       -       -  ...  102.06  102.96  103.83  104.41
# 2    도심권       -       -       -  ...  101.18  101.33  101.80  102.11
# 3    동북권       -       -       -  ...  102.43  103.71  104.82  105.50
# 4    서북권       -       -       -  ...  101.19  101.10  101.36  101.72
# 5   강남지역       -       -       -  ...  101.55  102.47  103.47  104.27
# 6    서남권       -       -       -  ...  101.28  102.13  103.09  103.60
# 7    동남권       -       -       -  ...  101.87  102.89  103.93  105.09
#
# [8 rows x 120 columns]

# %%
SSize_1 = SSize_1.transpose()
SSize_1.rename(columns=SSize_1.iloc[0], inplace=True)
SSize_1 = SSize_1.drop(SSize_1.index[0])
SSize_1 = SSize_1.reset_index()
SSize_1.rename(columns = {'index':'날짜'}, inplace=True)

# %%
SSize_1
# Out:
#           날짜   서울특별시    강북지역     도심권     동북권     서북권    강남지역     서남권     동남권
# 0    2012-01       -       -       -       -       -       -       -       -
# 1    2012-02       -       -       -       -       -       -       -       -
# 2    2012-03       -       -       -       -       -       -       -       -
# 3    2012-04       -       -       -       -       -       -       -       -
# 4    2012-05       -       -       -       -       -       -       -       -
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 114  2021-07  100.76  100.92  100.37  101.13  100.48  100.63  100.56  100.72
# 115  2021-08  101.77  102.06  101.18  102.43  101.19  101.55  101.28  101.87
# 116  2021-09  102.69  102.96  101.33  103.71  101.10  102.47  102.13  102.89
# 117  2021-10  103.63  103.83  101.80  104.82  101.36  103.47  103.09  103.93
# 118  2021-11  104.34  104.41  102.11  105.50  101.72  104.27  103.60  105.09
#
# [119 rows x 9 columns]

# %%
SSize_1.insert(1, '크기', '초소형')

# %%
SSize_1.insert(1, '구분', '매매')

# %%
SSize_1 = SSize_1[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
SSize_1
# Out:
#           날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  초소형       -       -  ...       -       -       -       -       -
# 1    2012-02  매매  초소형       -       -  ...       -       -       -       -       -
# 2    2012-03  매매  초소형       -       -  ...       -       -       -       -       -
# 3    2012-04  매매  초소형       -       -  ...       -       -       -       -       -
# 4    2012-05  매매  초소형       -       -  ...       -       -       -       -       -
# ..       ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  매매  초소형  100.76  100.37  ...  101.13  100.48  100.63  100.72  100.56
# 115  2021-08  매매  초소형  101.77  101.18  ...  102.43  101.19  101.55  101.87  101.28
# 116  2021-09  매매  초소형  102.69  101.33  ...  103.71  101.10  102.47  102.89  102.13
# 117  2021-10  매매  초소형  103.63  101.80  ...  104.82  101.36  103.47  103.93  103.09
# ...

# %%
SSize_2
# Out:
#        지역             규모 2012-01 2012-02  ... 2021-08 2021-09 2021-10 2021-11
# 8   서울특별시  40㎡초과 ~ 60㎡이하   71.83   71.74  ...  102.15  103.20  104.17  104.79
# 9    강북지역  40㎡초과 ~ 60㎡이하   73.37   73.32  ...  102.39  103.41  104.28  104.85
# 10    도심권  40㎡초과 ~ 60㎡이하   72.52   72.42  ...  101.37  102.35  103.86  105.28
# 11    동북권  40㎡초과 ~ 60㎡이하   74.22   74.22  ...  102.63  103.63  104.36  104.85
# 12    서북권  40㎡초과 ~ 60㎡이하   69.78   69.55  ...  101.73  102.88  104.09  104.73
# 13   강남지역  40㎡초과 ~ 60㎡이하   70.14   70.02  ...  101.86  102.94  104.04  104.71
# 14    서남권  40㎡초과 ~ 60㎡이하   72.08   72.08  ...  101.74  102.93  103.85  104.41
# 15    동남권  40㎡초과 ~ 60㎡이하   67.35   67.09  ...  102.05  102.97  104.34  105.20
#
# [8 rows x 121 columns]

# %%
SSize_2 = SmallSize_deal['규모'] == '40㎡초과 ~ 60㎡이하'
SSize_2 = SmallSize_deal[SSize_2]
SSize_2.drop(columns='규모', inplace=True)
SSize_2
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        지역 2012-01 2012-02 2012-03  ... 2021-08 2021-09 2021-10 2021-11
# 8   서울특별시   71.83   71.74   71.47  ...  102.15  103.20  104.17  104.79
# 9    강북지역   73.37   73.32   73.10  ...  102.39  103.41  104.28  104.85
# 10    도심권   72.52   72.42   72.47  ...  101.37  102.35  103.86  105.28
# 11    동북권   74.22   74.22   73.96  ...  102.63  103.63  104.36  104.85
# 12    서북권   69.78   69.55   69.36  ...  101.73  102.88  104.09  104.73
# 13   강남지역   70.14   70.02   69.70  ...  101.86  102.94  104.04  104.71
# 14    서남권   72.08   72.08   71.71  ...  101.74  102.93  103.85  104.41
# 15    동남권   67.35   67.09   66.84  ...  102.05  102.97  104.34  105.20
#
# ...

# %%
SSize_2 = SSize_2.transpose()
SSize_2.rename(columns=SSize_2.iloc[0], inplace=True)
SSize_2 = SSize_2.drop(SSize_2.index[0])
SSize_2 = SSize_2.reset_index()
SSize_2.rename(columns = {'index':'날짜'}, inplace=True)
SSize_2.insert(2, '크기', '소형') 
SSize_2.insert(2, '구분', '매매') 
SSize_2 = SSize_2[['날짜','구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
SSize_2
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  소형   71.83   72.52  ...   74.22   69.78   70.14   67.35   72.08
# 1    2012-02  매매  소형   71.74   72.42  ...   74.22   69.55   70.02   67.09   72.08
# 2    2012-03  매매  소형   71.47   72.47  ...   73.96   69.36   69.70   66.84   71.71
# 3    2012-04  매매  소형   71.14   72.47  ...   73.56   69.21   69.38   66.62   71.29
# 4    2012-05  매매  소형   70.74   72.36  ...   73.02   68.99   69.04   66.43   70.81
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  매매  소형  101.01  100.54  ...  101.28  100.86  100.84  100.94  100.78
# 115  2021-08  매매  소형  102.15  101.37  ...  102.63  101.73  101.86  102.05  101.74
# 116  2021-09  매매  소형  103.20  102.35  ...  103.63  102.88  102.94  102.97  102.93
# 117  2021-10  매매  소형  104.17  103.86  ...  104.36  104.09  104.04  104.34  103.85
# ...

# %%
SSize_3 = SmallSize_charter['규모'] == '40㎡이하'
SSize_3 = SmallSize_charter[SSize_3]
SSize_3
# Out:
#    Unnamed: 0     지역     규모 2012-01  ... 2021-08 2021-09 2021-10 2021-11
# 0           0  서울특별시  40㎡이하       -  ...  100.66  101.25  101.72  101.87
# 1           1   강북지역  40㎡이하       -  ...  100.47  100.78  101.21  101.49
# 2           2    도심권  40㎡이하       -  ...  100.11  100.56  100.79  101.15
# 3           3    동북권  40㎡이하       -  ...  100.55  100.92  101.47  101.72
# 4           4    서북권  40㎡이하       -  ...  100.43  100.40  100.46  100.82
# 5           5   강남지역  40㎡이하       -  ...  100.81  101.62  102.13  102.18
# 6           6    서남권  40㎡이하       -  ...  100.53  100.88  100.84  100.63
# 7           7    동남권  40㎡이하       -  ...  101.15  102.52  103.72  104.10
#
# [8 rows x 122 columns]

# %%
SSize_3.drop(columns='규모', inplace=True)
SSize_3.drop(columns='Unnamed: 0', inplace=True)
SSize_3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       지역 2012-01 2012-02 2012-03  ... 2021-08 2021-09 2021-10 2021-11
# 0  서울특별시       -       -       -  ...  100.66  101.25  101.72  101.87
# 1   강북지역       -       -       -  ...  100.47  100.78  101.21  101.49
# 2    도심권       -       -       -  ...  100.11  100.56  100.79  101.15
# 3    동북권       -       -       -  ...  100.55  100.92  101.47  101.72
# 4    서북권       -       -       -  ...  100.43  100.40  100.46  100.82
# 5   강남지역       -       -       -  ...  100.81  101.62  102.13  102.18
# 6    서남권       -       -       -  ...  100.53  100.88  100.84  100.63
# 7    동남권       -       -       -  ...  101.15  102.52  103.72  104.10
#
# [8 rows x 120 columns]

# %%
SSize_3 = SSize_3.transpose()
SSize_3
# Out:
#               0       1       2       3       4       5       6       7
# 지역        서울특별시    강북지역     도심권     동북권     서북권    강남지역     서남권     동남권
# 2012-01       -       -       -       -       -       -       -       -
# 2012-02       -       -       -       -       -       -       -       -
# 2012-03       -       -       -       -       -       -       -       -
# 2012-04       -       -       -       -       -       -       -       -
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.24  100.08  100.00  100.04  100.35  100.37  100.15  100.63
# 2021-08  100.66  100.47  100.11  100.55  100.43  100.81  100.53  101.15
# 2021-09  101.25  100.78  100.56  100.92  100.40  101.62  100.88  102.52
# 2021-10  101.72  101.21  100.79  101.47  100.46  102.13  100.84  103.72
# 2021-11  101.87  101.49  101.15  101.72  100.82  102.18  100.63  104.10
#
# [120 rows x 8 columns]

# %%
SSize_3.rename(columns=SSize_3.iloc[0], inplace=True)
SSize_3 = SSize_3.drop(SSize_3.index[0])
SSize_3
# Out:
#           서울특별시    강북지역     도심권     동북권     서북권    강남지역     서남권     동남권
# 2012-01       -       -       -       -       -       -       -       -
# 2012-02       -       -       -       -       -       -       -       -
# 2012-03       -       -       -       -       -       -       -       -
# 2012-04       -       -       -       -       -       -       -       -
# 2012-05       -       -       -       -       -       -       -       -
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.24  100.08  100.00  100.04  100.35  100.37  100.15  100.63
# 2021-08  100.66  100.47  100.11  100.55  100.43  100.81  100.53  101.15
# 2021-09  101.25  100.78  100.56  100.92  100.40  101.62  100.88  102.52
# 2021-10  101.72  101.21  100.79  101.47  100.46  102.13  100.84  103.72
# 2021-11  101.87  101.49  101.15  101.72  100.82  102.18  100.63  104.10
#
# [119 rows x 8 columns]

# %%
SSize_3 = SSize_3.reset_index()
SSize_3.rename(columns = {'index':'날짜'}, inplace=True)
SSize_3.insert(2, '크기', '초소형') 
SSize_3.insert(2, '구분', '전세')
SSize_3 = SSize_3[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
SSize_3
# Out:
#           날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  전세  초소형       -       -  ...       -       -       -       -       -
# 1    2012-02  전세  초소형       -       -  ...       -       -       -       -       -
# 2    2012-03  전세  초소형       -       -  ...       -       -       -       -       -
# 3    2012-04  전세  초소형       -       -  ...       -       -       -       -       -
# 4    2012-05  전세  초소형       -       -  ...       -       -       -       -       -
# ..       ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  전세  초소형  100.24  100.00  ...  100.04  100.35  100.37  100.63  100.15
# 115  2021-08  전세  초소형  100.66  100.11  ...  100.55  100.43  100.81  101.15  100.53
# 116  2021-09  전세  초소형  101.25  100.56  ...  100.92  100.40  101.62  102.52  100.88
# 117  2021-10  전세  초소형  101.72  100.79  ...  101.47  100.46  102.13  103.72  100.84
# ...

# %%
SSize_4 = SmallSize_charter['규모'] == '40㎡초과 ~ 60㎡이하'
SSize_4 = SmallSize_charter[SSize_4]
SSize_4.drop(columns='규모', inplace=True)
SSize_4.drop(columns='Unnamed: 0', inplace=True)
SSize_4 = SSize_4.transpose()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
SSize_4.rename(columns=SSize_4.iloc[0], inplace=True)
SSize_4 = SSize_4.drop(SSize_4.index[0])
SSize_4
# Out:
#           서울특별시    강북지역     도심권     동북권     서북권    강남지역     서남권     동남권
# 2012-01   68.76   68.09   67.54   68.31   67.29   69.50   66.31   73.80
# 2012-02   68.80   68.19   67.58   68.39   67.54   69.45   66.55   73.37
# 2012-03   68.76   68.15   67.83   68.29   67.67   69.42   66.43   73.46
# 2012-04   68.58   67.97   67.91   68.03   67.76   69.24   66.09   73.47
# 2012-05   68.26   67.62   67.89   67.54   67.99   68.95   65.71   73.31
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.78  100.76  100.55  100.80  100.65  100.81  100.97  100.54
# 2021-08  101.72  101.59  101.48  101.61  101.57  101.87  101.78  102.01
# 2021-09  102.42  102.23  102.20  102.25  102.17  102.65  102.48  102.92
# 2021-10  102.98  102.78  103.53  102.63  103.15  103.23  103.00  103.60
# 2021-11  103.56  103.26  104.26  103.04  103.83  103.91  103.68  104.28
#
# [119 rows x 8 columns]

# %%
SSize_4 = SSize_4.reset_index()
SSize_4.rename(columns = {'index':'날짜'}, inplace=True)
SSize_4.insert(2, '크기', '소형') 
SSize_4.insert(2, '구분', '전세') 
SSize_4 = SSize_4[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
SSize_4
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  전세  소형   68.76   67.54  ...   68.31   67.29   69.50   73.80   66.31
# 1    2012-02  전세  소형   68.80   67.58  ...   68.39   67.54   69.45   73.37   66.55
# 2    2012-03  전세  소형   68.76   67.83  ...   68.29   67.67   69.42   73.46   66.43
# 3    2012-04  전세  소형   68.58   67.91  ...   68.03   67.76   69.24   73.47   66.09
# 4    2012-05  전세  소형   68.26   67.89  ...   67.54   67.99   68.95   73.31   65.71
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 114  2021-07  전세  소형  100.78  100.55  ...  100.80  100.65  100.81  100.54  100.97
# 115  2021-08  전세  소형  101.72  101.48  ...  101.61  101.57  101.87  102.01  101.78
# 116  2021-09  전세  소형  102.42  102.20  ...  102.25  102.17  102.65  102.92  102.48
# 117  2021-10  전세  소형  102.98  103.53  ...  102.63  103.15  103.23  103.60  103.00
# ...

# %%
SSize_5 = SmallSize_rent['규모'] == '40㎡이하'
SSize_5 = SmallSize_rent[SSize_5]
SSize_5.drop(columns='규모', inplace=True)
SSize_5.drop(columns='Unnamed: 0', inplace=True)
SSize_5 = SSize_5.transpose()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
SSize_5.rename(columns=SSize_5.iloc[0], inplace=True)
SSize_5 = SSize_5.drop(SSize_5.index[0])
SSize_5
# Out:
#           서울특별시    강북지역     도심권     동북권     서북권    강남지역     서남권     동남권
# 2015-06       -       -       -       -       -       -       -       -
# 2015-07       -       -       -       -       -       -       -       -
# 2015-08       -       -       -       -       -       -       -       -
# 2015-09       -       -       -       -       -       -       -       -
# 2015-10       -       -       -       -       -       -       -       -
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.24  100.40  100.04  100.52  100.18  100.10  100.26   99.91
# 2021-08  100.86  100.85  100.38  100.93  100.85  100.86  100.75  101.00
# 2021-09  101.05  101.00  100.63  101.08  100.96  101.08  101.00  101.19
# 2021-10  101.18  101.01  100.83  101.01  101.13  101.32  101.15  101.52
# 2021-11  101.52  101.28  101.58  101.20  101.38  101.70  101.55  101.89
#
# [78 rows x 8 columns]

# %%
SSize_5 = SSize_5.reset_index()
SSize_5.rename(columns = {'index':'날짜'}, inplace=True)
SSize_5.insert(2, '크기', '초소형') 
SSize_5.insert(2, '구분', '월세')
SSize_5 = SSize_5[['날짜','구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
SSize_5
# Out:
#          날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0   2015-06  월세  초소형       -       -  ...       -       -       -       -       -
# 1   2015-07  월세  초소형       -       -  ...       -       -       -       -       -
# 2   2015-08  월세  초소형       -       -  ...       -       -       -       -       -
# 3   2015-09  월세  초소형       -       -  ...       -       -       -       -       -
# 4   2015-10  월세  초소형       -       -  ...       -       -       -       -       -
# ..      ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 73  2021-07  월세  초소형  100.24  100.04  ...  100.52  100.18  100.10   99.91  100.26
# 74  2021-08  월세  초소형  100.86  100.38  ...  100.93  100.85  100.86  101.00  100.75
# 75  2021-09  월세  초소형  101.05  100.63  ...  101.08  100.96  101.08  101.19  101.00
# 76  2021-10  월세  초소형  101.18  100.83  ...  101.01  101.13  101.32  101.52  101.15
# ...

# %%
SSize_6 = SmallSize_rent['규모'] == '40㎡초과 ~ 60㎡이하'
SSize_6 = SmallSize_rent[SSize_6]
SSize_6.drop(columns='규모', inplace=True)
SSize_6.drop(columns='Unnamed: 0', inplace=True)
SSize_6 = SSize_6.transpose()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
SSize_6.rename(columns=SSize_6.iloc[0], inplace=True)
SSize_6 = SSize_6.drop(SSize_6.index[0])
SSize_6
# Out:
#           서울특별시    강북지역     도심권     동북권     서북권    강남지역     서남권     동남권
# 2015-06   97.36   97.71   97.81   97.91   96.78   96.97   96.83   97.03
# 2015-07   97.37   97.71   97.58   97.90   96.93   97.01   96.77   97.17
# 2015-08   97.44   97.78   97.47   97.99   97.01   97.07   96.77   97.31
# 2015-09   97.66   97.96   97.62   98.21   97.00   97.34   96.99   97.64
# 2015-10   97.82   97.99   97.67   98.24   97.00   97.62   97.17   98.05
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07  100.22  100.19  100.63  100.17  100.12  100.26  100.09  100.54
# 2021-08  100.61  100.66  101.02  100.71  100.32  100.55  100.34  100.89
# 2021-09  100.94  100.90  101.39  100.98  100.39  101.00  100.60  101.64
# 2021-10  101.23  101.20  101.75  101.31  100.55  101.26  100.58  102.36
# 2021-11  101.60  101.66  102.09  101.77  101.05  101.54  100.62  103.04
#
# [78 rows x 8 columns]

# %%
SSize_6 = SSize_6.reset_index()
SSize_6.rename(columns = {'index':'날짜'}, inplace=True)
SSize_6.insert(2, '크기', '소형') 
SSize_6.insert(2, '구분', '월세') 
SSize_6 = SSize_6[['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권']]
SSize_6
# Out:
#          날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0   2015-06  월세  소형   97.36   97.81  ...   97.91   96.78   96.97   97.03   96.83
# 1   2015-07  월세  소형   97.37   97.58  ...   97.90   96.93   97.01   97.17   96.77
# 2   2015-08  월세  소형   97.44   97.47  ...   97.99   97.01   97.07   97.31   96.77
# 3   2015-09  월세  소형   97.66   97.62  ...   98.21   97.00   97.34   97.64   96.99
# 4   2015-10  월세  소형   97.82   97.67  ...   98.24   97.00   97.62   98.05   97.17
# ..      ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 73  2021-07  월세  소형  100.22  100.63  ...  100.17  100.12  100.26  100.54  100.09
# 74  2021-08  월세  소형  100.61  101.02  ...  100.71  100.32  100.55  100.89  100.34
# 75  2021-09  월세  소형  100.94  101.39  ...  100.98  100.39  101.00  101.64  100.60
# 76  2021-10  월세  소형  101.23  101.75  ...  101.31  100.55  101.26  102.36  100.58
# 77  2021-11  월세  소형  101.60  102.09  ...  101.77  101.05  101.54  103.04  100.62
#
# ...

# %% [markdown]
# SSize_1,3,5 = 초소형
# SSize_2,4,6 = 소형

# %% [markdown]
# ## 초소형 합본(~40)

# %%
SmallSize_1 = pd.merge(left=SSize_1, right=SSize_3, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
SmallSize_1 = SmallSize_1.sort_values(by='날짜')
SmallSize_1 = SmallSize_1.reset_index()
SmallSize_1.drop(columns='index', inplace=True)
SmallSize_1 = pd.merge(left=SmallSize_1, right=SSize_5, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
SmallSize_1 = SmallSize_1.sort_values(by='날짜')
SmallSize_1 = SmallSize_1.reset_index()
SmallSize_1.drop(columns='index', inplace=True)
SmallSize_1
# Out:
#           날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  초소형       -       -  ...       -       -       -       -       -
# 1    2012-01  전세  초소형       -       -  ...       -       -       -       -       -
# 2    2012-02  매매  초소형       -       -  ...       -       -       -       -       -
# 3    2012-02  전세  초소형       -       -  ...       -       -       -       -       -
# 4    2012-03  매매  초소형       -       -  ...       -       -       -       -       -
# ..       ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 311  2021-10  매매  초소형  103.63  101.80  ...  104.82  101.36  103.47  103.93  103.09
# 312  2021-10  월세  초소형  101.18  100.83  ...  101.01  101.13  101.32  101.52  101.15
# 313  2021-11  매매  초소형  104.34  102.11  ...  105.50  101.72  104.27  105.09  103.60
# 314  2021-11  전세  초소형  101.87  101.15  ...  101.72  100.82  102.18  104.10  100.63
# ...

# %% [markdown]
# ## 소형 합본(40~60)

# %%
SmallSize_2 = pd.merge(left=SSize_2, right=SSize_4, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
SmallSize_2 = SmallSize_2.sort_values(by='날짜')
SmallSize_2 = SmallSize_2.reset_index()
SmallSize_2.drop(columns='index', inplace=True)
SmallSize_2 = pd.merge(left=SmallSize_2, right=SSize_6, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
SmallSize_2 = SmallSize_2.sort_values(by='날짜')
SmallSize_2 = SmallSize_2.reset_index()
SmallSize_2.drop(columns='index', inplace=True)
SmallSize_2
# Out:
#           날짜  구분  크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  소형   71.83   72.52  ...   74.22   69.78   70.14   67.35   72.08
# 1    2012-01  전세  소형   68.76   67.54  ...   68.31   67.29   69.50   73.80   66.31
# 2    2012-02  매매  소형   71.74   72.42  ...   74.22   69.55   70.02   67.09   72.08
# 3    2012-02  전세  소형   68.80   67.58  ...   68.39   67.54   69.45   73.37   66.55
# 4    2012-03  매매  소형   71.47   72.47  ...   73.96   69.36   69.70   66.84   71.71
# ..       ...  ..  ..     ...     ...  ...     ...     ...     ...     ...     ...
# 311  2021-10  매매  소형  104.17  103.86  ...  104.36  104.09  104.04  104.34  103.85
# 312  2021-10  월세  소형  101.23  101.75  ...  101.31  100.55  101.26  102.36  100.58
# 313  2021-11  매매  소형  104.79  105.28  ...  104.85  104.73  104.71  105.20  104.41
# 314  2021-11  전세  소형  103.56  104.26  ...  103.04  103.83  103.91  104.28  103.68
# ...

# %%
SmallSize = pd.merge(left=SmallSize_1, right=SmallSize_2, on= ['날짜', '구분', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
SmallSize = SmallSize.sort_values(by='날짜')
SmallSize = SmallSize.reset_index()
SmallSize.drop(columns='index', inplace=True)
SmallSize
# Out:
#           날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  초소형       -       -  ...       -       -       -       -       -
# 1    2012-01  전세  초소형       -       -  ...       -       -       -       -       -
# 2    2012-01  매매   소형   71.83   72.52  ...   74.22   69.78   70.14   67.35   72.08
# 3    2012-01  전세   소형   68.76   67.54  ...   68.31   67.29   69.50   73.80   66.31
# 4    2012-02  매매  초소형       -       -  ...       -       -       -       -       -
# ..       ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 627  2021-11  월세  초소형  101.52  101.58  ...  101.20  101.38  101.70  101.89  101.55
# 628  2021-11  전세  초소형  101.87  101.15  ...  101.72  100.82  102.18  104.10  100.63
# 629  2021-11  매매  초소형  104.34  102.11  ...  105.50  101.72  104.27  105.09  103.60
# 630  2021-11  전세   소형  103.56  104.26  ...  103.04  103.83  103.91  104.28  103.68
# ...

# %%
SmallSize
# Out:
#           날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  초소형       -       -  ...       -       -       -       -       -
# 1    2012-01  전세  초소형       -       -  ...       -       -       -       -       -
# 2    2012-01  매매   소형   71.83   72.52  ...   74.22   69.78   70.14   67.35   72.08
# 3    2012-01  전세   소형   68.76   67.54  ...   68.31   67.29   69.50   73.80   66.31
# 4    2012-02  매매  초소형       -       -  ...       -       -       -       -       -
# ..       ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 627  2021-11  월세  초소형  101.52  101.58  ...  101.20  101.38  101.70  101.89  101.55
# 628  2021-11  전세  초소형  101.87  101.15  ...  101.72  100.82  102.18  104.10  100.63
# 629  2021-11  매매  초소형  104.34  102.11  ...  105.50  101.72  104.27  105.09  103.60
# 630  2021-11  전세   소형  103.56  104.26  ...  103.04  103.83  103.91  104.28  103.68
# ...

# %%
idx = SmallSize[SmallSize['서울특별시'] == 0].index
SmallSize.drop(idx, inplace=True)

# %%
SmallSize
# Out:
#           날짜  구분   크기   서울특별시     도심권  ...     동북권     서북권    강남지역     동남권     서남권
# 0    2012-01  매매  초소형       -       -  ...       -       -       -       -       -
# 1    2012-01  전세  초소형       -       -  ...       -       -       -       -       -
# 2    2012-01  매매   소형   71.83   72.52  ...   74.22   69.78   70.14   67.35   72.08
# 3    2012-01  전세   소형   68.76   67.54  ...   68.31   67.29   69.50   73.80   66.31
# 4    2012-02  매매  초소형       -       -  ...       -       -       -       -       -
# ..       ...  ..  ...     ...     ...  ...     ...     ...     ...     ...     ...
# 627  2021-11  월세  초소형  101.52  101.58  ...  101.20  101.38  101.70  101.89  101.55
# 628  2021-11  전세  초소형  101.87  101.15  ...  101.72  100.82  102.18  104.10  100.63
# 629  2021-11  매매  초소형  104.34  102.11  ...  105.50  101.72  104.27  105.09  103.60
# 630  2021-11  전세   소형  103.56  104.26  ...  103.04  103.83  103.91  104.28  103.68
# ...

# %%
SmallSize.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/초소형-소형 가격지수(총합).csv')

# %% [markdown]
# # 평수 가격지수 총합

# %%
Total = pd.merge(left=LargeSize, right=MiddleSize, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total = Total.sort_values(by='날짜')
Total = Total.reset_index()
Total.drop(columns='index', inplace=True)
Total
# Out:
#           날짜 구분_x  크기   서울특별시     도심권  ...     서북권    강남지역     동남권     서남권  구분_y
# 0    2012-01   매매  대형   90.63   95.75  ...   90.26   88.39   86.63   92.43   NaN
# 1    2012-01   전세  대형   74.16   79.66  ...   78.88   72.95   75.07   70.94   NaN
# 2    2012-01  NaN  중형   79.55   87.46  ...   84.25   77.05   75.14   79.24    매매
# 3    2012-01  NaN  중형   70.02   69.94  ...   72.66   69.03   71.03   66.42    전세
# 4    2012-02   매매  대형   90.17   95.72  ...   90.23   87.83   85.85   92.33   NaN
# ..       ...  ...  ..     ...     ...  ...     ...     ...     ...     ...   ...
# 627  2021-11   월세  대형  101.18  100.70  ...  102.09  101.25  101.61  100.49   NaN
# 628  2021-11   전세  대형  102.71  102.63  ...  102.54  102.88  102.99  102.63   NaN
# 629  2021-11   매매  대형  103.49  103.51  ...  103.06  103.90  104.44  102.65   NaN
# 630  2021-11  NaN  중형  103.11  103.73  ...  102.21  103.21  103.28  103.13    전세
# 631  2021-11  NaN  중형  100.94  101.54  ...  101.49  101.02  101.47  100.69    월세
#
# ...

# %%
Total = pd.merge(left=Total, right=SmallSize, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total = Total.sort_values(by=['날짜', '크기'] ,ascending=True)
Total = Total.reset_index()
Total.drop(columns='index', inplace=True)
Total
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-267-f3dd3d3f36e2> in <module>()
# ----> 1 Total = pd.merge(left=Total, right=SmallSize, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
#       2 Total = Total.sort_values(by=['날짜', '크기'] ,ascending=True)
#       3 Total = Total.reset_index()
#       4 Total.drop(columns='index', inplace=True)
#       5 Total
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in get_result(self)
#     688             result = self._indicator_post_merge(result)
#     689
# ...

# %%
Total.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/평수별 가격지수 총합.csv')

# %% [markdown]
# # 아파트 전체 매매/전세/월세 가격 지수
# - 전체 매매 지수
# - 전체 전세 지수
# - 전체 월세 지수
# - 총합

# %%
LargeSize_deal_group.head()

# %%
MiddleSize_deal_group.head()

# %%
SSize_1.head()

# %%
SSize_2.head()

# %% [markdown]
# ## 매매 가격 지수

# %%
Total_1 = pd.merge(left=LargeSize_deal_group, right=MiddleSize_deal_group, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_1 = Total_1.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_1 = Total_1.reset_index()
Total_1.drop(columns='index', inplace=True)
Total_1

# %%
SSize_1 = SSize_1.replace('-', 0)

# %%
Total_1 = pd.merge(left=Total_1, right=SSize_1, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_1 = Total_1.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_1 = Total_1.reset_index()
Total_1.drop(columns='index', inplace=True)
Total_1

# %%
Total_1 = pd.merge(left=Total_1, right=SSize_2, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_1 = Total_1.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_1 = Total_1.reset_index()
Total_1.drop(columns='index', inplace=True)
Total_1

# %%
Total_1 = Total_1.groupby(Total_1['날짜']).mean()

# %%
Total_1 = Total_1.reset_index()
Total_1

# %%
Total_1.insert(1, '구분', '매매')
Total_1

# %%
Total_1.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/서울시 매매 가격지수 총합.csv')

# %% [markdown]
# SSize_1,3,5 = 초소형
# SSize_2,4,6 = 소형

# %% [markdown]
# ## 전세 가격 지수

# %%
SSize_3 = SSize_3.replace('-', 0)

# %%
Total_2 = pd.merge(left=LargeSize_charter_group, right=MiddleSize_charter_group, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_2 = Total_2.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_2 = Total_2.reset_index()
Total_2.drop(columns='index', inplace=True)
Total_2

# %%
Total_2 = pd.merge(left=Total_2, right=SSize_3, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_2 = Total_2.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_2 = Total_2.reset_index()
Total_2.drop(columns='index', inplace=True)
Total_2

# %%
Total_2 = pd.merge(left=Total_2, right=SSize_4, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_2 = Total_2.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_2 = Total_2.reset_index()
Total_2.drop(columns='index', inplace=True)
Total_2 = Total_2.groupby(Total_2['날짜']).mean()
Total_2 = Total_2.reset_index()
Total_2

# %%
Total_2.insert(1, '구분', '전세')
Total_2

# %%
Total_2.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/서울시 전세 가격지수 총합.csv')

# %% [markdown]
# ## 월세 가격 지수

# %%
SSize_5 = SSize_5.replace('-', 0)

# %%
Total_3 = pd.merge(left=LargeSize_rent_group, right=MiddleSize_rent_group, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_3 = Total_3.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_3 = Total_3.reset_index()
Total_3.drop(columns='index', inplace=True)
Total_3

# %%
Total_3 = pd.merge(left=Total_3, right=SSize_5, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_3 = Total_3.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_3 = Total_3.reset_index()
Total_3.drop(columns='index', inplace=True)
Total_3

# %%
Total_3 = pd.merge(left=Total_3, right=SSize_6, on= ['날짜', '크기', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_3 = Total_3.sort_values(by=['날짜', '크기'] ,ascending=True)
Total_3 = Total_3.reset_index()
Total_3.drop(columns='index', inplace=True)
Total_3
Total_3 = Total_3.groupby(Total_3['날짜']).mean()
Total_3 = Total_3.reset_index()
Total_3

# %%
Total_3.insert(1, '구분', '월세')

# %%
Total_3

# %%
Total_3.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/전처리/서울시 월세 가격지수 총합.csv')

# %% [markdown]
# ### 종합

# %%
Total_4 = pd.merge(left=Total_1, right=Total_2, on= ['날짜', '구분', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_4 = Total_4.sort_values(by=['날짜', '구분'] ,ascending=True)
Total_4 = Total_4.reset_index()

# %%
Total_4

# %%
Total_4.drop(columns='index', inplace=True)

# %%
Total_4

# %%
Total_4 = pd.merge(left=Total_4, right=Total_3, on= ['날짜', '구분', '서울특별시', '도심권' , '강북지역', '동북권', '서북권', '강남지역', '동남권', '서남권'], how='outer')
Total_4 = Total_4.sort_values(by=['날짜', '구분'] ,ascending=True)
Total_4 = Total_4.reset_index()
Total_4.drop(columns='index', inplace=True)
Total_4

# %%
Total_4.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_3조/김장현/data/12.01_21.11 규모별_아파트_매매_평균가격.csv')
