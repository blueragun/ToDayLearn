# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import font_manager, rcParams
# !apt-get install fonts-nanum*
rcParams['font.family'] = 'NanumGothicCoding'
rcParams['axes.unicode_minus'] = False
font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-gothic-light' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# The following NEW packages will be installed:
#   fonts-nanum fonts-nanum-coding fonts-nanum-eco fonts-nanum-extra
# 0 upgraded, 4 newly installed, 0 to remove and 37 not upgraded.
# Need to get 37.0 MB of archives.
# After this operation, 145 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum-eco all 1.000-6 [14.0 MB]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 가격 지수

# %%
apc_data_1 = pd.read_excel('/content/drive/MyDrive/data/조사자료/서울시_주택가격지수통계(10-20).xls')
apc_data_1
# Out:
#        연도    자치구  ... 주택전세가격지수(2017.11=100.0) 주택전세가격지수(2017.11=100.0).1
# 0      기간    자치구  ...                      종합                       아파트
# 1    2010  서울특별시  ...                    73.4                      66.2
# 2    2010    종로구  ...                    81.9                        73
# 3    2010     중구  ...                    75.5                      67.5
# 4    2010    용산구  ...                    76.9                      68.7
# ..    ...    ...  ...                     ...                       ...
# 282  2020    관악구  ...                   103.3                     106.6
# 283  2020    서초구  ...                   104.2                     105.3
# 284  2020    강남구  ...                   103.9                     105.4
# 285  2020    송파구  ...                   104.3                     106.1
# 286  2020    강동구  ...                    99.4                      99.4
#
# [287 rows x 6 columns]

# %% [markdown]
# ## 이름 변경

# %%
apc_data_1.loc[apc_data_1['자치구'] == '서울시', '자치구'] = '서울특별시'

# %%
apc_data_1
# Out:
#        연도    자치구  ... 주택전세가격지수(2017.11=100.0) 주택전세가격지수(2017.11=100.0).1
# 0      기간    자치구  ...                      종합                       아파트
# 1    2010  서울특별시  ...                    73.4                      66.2
# 2    2010    종로구  ...                    81.9                        73
# 3    2010     중구  ...                    75.5                      67.5
# 4    2010    용산구  ...                    76.9                      68.7
# ..    ...    ...  ...                     ...                       ...
# 282  2020    관악구  ...                   103.3                     106.6
# 283  2020    서초구  ...                   104.2                     105.3
# 284  2020    강남구  ...                   103.9                     105.4
# 285  2020    송파구  ...                   104.3                     106.1
# 286  2020    강동구  ...                    99.4                      99.4
#
# [287 rows x 6 columns]

# %%
apc_data_1.to_excel('/content/drive/MyDrive/data/조사자료/서울시_주택가격지수통계(10-20).xls', index=False)

# %% [markdown]
# ## 해당 구 위도 및 경도 삽입시 사용

# %%
apc_data_1.loc['서울특별시', '위도'] = 37.335887
apc_data_1.loc['종로구', '위도'] = 37.3427
apc_data_1.loc['중구', '위도'] = 37.3349
apc_data_1.loc['용산구', '위도'] = 37.3156
apc_data_1.loc['동작구', '위도'] = 37.3044
apc_data_1.loc['관악구', '위도'] = 37.2843
apc_data_1.loc['은평구', '위도'] = 37.3617
apc_data_1.loc['서대문구', '위도'] = 37.3459
apc_data_1.loc['마포구', '위도'] = 37.3341
apc_data_1.loc['영등포구', '위도'] = 37.3115
apc_data_1.loc['구로구', '위도'] = 37.2944
apc_data_1.loc['금천구', '위도'] = 37.2735
apc_data_1.loc['강서구', '위도'] = 37.3402
apc_data_1.loc['양천구', '위도'] = 37.3138
apc_data_1.loc['도봉구', '위도'] = 37.3958
apc_data_1.loc['강북구', '위도'] = 37.3853
apc_data_1.loc['성북구', '위도'] = 37.3608
apc_data_1.loc['동대문구', '위도'] = 37.3500
apc_data_1.loc['성동구', '위도'] = 37.3355
apc_data_1.loc['서초구', '위도'] = 37.2833
apc_data_1.loc['강남구', '위도'] = 37.2948
apc_data_1.loc['노원구', '위도'] = 37.3915
apc_data_1.loc['중랑구', '위도'] = 37.3542
apc_data_1.loc['광진구', '위도'] = 37.3246
apc_data_1.loc['송파구', '위도'] = 37.3017
apc_data_1.loc['강동구', '위도'] = 37.3256

# %%
apc_data_1.loc['서울특별시', '경도'] = 126.584063
apc_data_1.loc['종로구', '경도'] = 126.5846
apc_data_1.loc['중구', '경도'] = 126.5951
apc_data_1.loc['용산구', '경도'] = 126.5924
apc_data_1.loc['동작구', '경도'] = 126.5623
apc_data_1.loc['관악구', '경도'] = 126.5703
apc_data_1.loc['은평구', '경도'] = 126.5543
apc_data_1.loc['서대문구', '경도'] = 126.5608
apc_data_1.loc['마포구', '경도'] = 126.5431
apc_data_1.loc['영등포구', '경도'] = 126.5447
apc_data_1.loc['구로구', '경도'] = 126.5128
apc_data_1.loc['금천구', '경도'] = 126.5404
apc_data_1.loc['강서구', '경도'] = 126.4924
apc_data_1.loc['양천구', '경도'] = 126.5121
apc_data_1.loc['도봉구', '경도'] = 127.0147
apc_data_1.loc['강북구', '경도'] = 127.0059
apc_data_1.loc['성북구', '경도'] = 127.0130
apc_data_1.loc['동대문구', '경도'] = 127.0301
apc_data_1.loc['성동구', '경도'] = 127.0242
apc_data_1.loc['서초구', '경도'] = 127.0213
apc_data_1.loc['강남구', '경도'] = 127.0404
apc_data_1.loc['노원구', '경도'] = 127.0437
apc_data_1.loc['중랑구', '경도'] = 127.0544
apc_data_1.loc['광진구', '경도'] = 127.0509
apc_data_1.loc['송파구', '경도'] = 127.0652
apc_data_1.loc['강동구', '경도'] = 127.0847

# %% [markdown]
# # 규모별 아파트 매매 가격지수

# %% [markdown]
# ### 도심권별 아파트 매매 지수

# %%
apc_data_2 = pd.read_excel('/content/drive/MyDrive/data/신규자료/규모별_매매가격지수_아파트.xlsx')
apc_data_2.head(2)
# Out:
#   지 역             규모 2012년 01월  ...   2021년 09월   2021년 10월   2021년 11월
# 0  서울          40㎡이하         -  ...  102.685641  103.629178  104.335195
# 1  서울  40㎡초과 ~ 60㎡이하   71.8267  ...  103.197712  104.170438  104.789905
#
# [2 rows x 121 columns]

# %%
from datetime import datetime

# %%
import datetime

# %%
names = []
for name in apc_data_2.columns[2:]:
  name = pd.to_datetime(name, format='%Y년 %m월')
  names.append(name.strftime('%Y-%m'))
print(names)
# Out:
# ['2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-0
# ...

# %%
names.insert(0, '규모')

# %%
names.insert(0, '지역')

# %%
apc_data_2.columns = names
apc_data_2.head(2)
# Out:
#    지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울          40㎡이하        -  ...  102.685641  103.629178  104.335195
# 1  서울  40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
#
# [2 rows x 121 columns]

# %%
apc_data_2.loc[apc_data_2['지역'] == '서울', '지역'] = '서울특별시'
apc_data_2.head(2)
# Out:
#       지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시          40㎡이하        -  ...  102.685641  103.629178  104.335195
# 1  서울특별시  40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
#
# [2 rows x 121 columns]

# %%
apc_data_2.transpose()
apc_data_2
# Out:
#        지역               규모  2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시            40㎡이하        -  ...  102.685641  103.629178  104.335195
# 1   서울특별시    40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
# 2   서울특별시    60㎡초과 ~ 85㎡이하  78.5747  ...  102.537131  103.383135  104.017918
# 3   서울특별시   85㎡초과 ~ 102㎡이하   80.531  ...  102.627636  103.240619  103.891569
# 4   서울특별시  102㎡초과 ~ 135㎡이하  87.6806  ...  102.145024  102.858093  103.381403
# 5   서울특별시           135㎡초과  93.5878  ...  102.298693  102.965753  103.608030
# 6    강북지역            40㎡이하        -  ...  102.956232  103.834502  104.413468
# 7    강북지역    40㎡초과 ~ 60㎡이하  73.3718  ...  103.411192  104.281339  104.854077
# 8    강북지역    60㎡초과 ~ 85㎡이하  81.8605  ...  102.276796  103.044533  103.570107
# 9    강북지역   85㎡초과 ~ 102㎡이하  85.7194  ...  102.189724  102.882344  103.306783
# 10   강북지역  102㎡초과 ~ 135㎡이하   92.252  ...  101.750645  102.371911  102.954339
# ...

# %% [markdown]
# #### 소형 평수(1㎡ ~ 60㎡이하)

# %%
SSize = apc_data_2['규모'] == '40㎡이하'
SmallSize1 = apc_data_2[SSize]

# %%
SmallSize1
# Out:
#        지역     규모 2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시  40㎡이하       -  ...  102.685641  103.629178  104.335195
# 6    강북지역  40㎡이하       -  ...  102.956232  103.834502  104.413468
# 12    도심권  40㎡이하       -  ...  101.330295  101.803374  102.111611
# 18    동북권  40㎡이하       -  ...  103.708387  104.816836  105.502076
# 24    서북권  40㎡이하       -  ...  101.103820  101.362431  101.717963
# 30   강남지역  40㎡이하       -  ...  102.470787  103.466051  104.272940
# 36    서남권  40㎡이하       -  ...  102.128339  103.087783  103.601847
# 42    동남권  40㎡이하       -  ...  102.888581  103.927709  105.094515
#
# [8 rows x 121 columns]

# %%
SSize = apc_data_2['규모'] == '40㎡초과 ~ 60㎡이하'
SmallSize2 = apc_data_2[SSize]

# %%
SmallSize2
# Out:
#        지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 1   서울특별시  40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
# 7    강북지역  40㎡초과 ~ 60㎡이하  73.3718  ...  103.411192  104.281339  104.854077
# 13    도심권  40㎡초과 ~ 60㎡이하  72.5237  ...  102.346946  103.861402  105.284437
# 19    동북권  40㎡초과 ~ 60㎡이하  74.2193  ...  103.625547  104.360768  104.848110
# 25    서북권  40㎡초과 ~ 60㎡이하  69.7842  ...  102.876230  104.091175  104.727760
# 31   강남지역  40㎡초과 ~ 60㎡이하  70.1421  ...  102.944743  104.038877  104.713742
# 37    서남권  40㎡초과 ~ 60㎡이하  72.0779  ...  102.929615  103.851393  104.408653
# 43    동남권  40㎡초과 ~ 60㎡이하   67.351  ...  102.969001  104.340182  105.204758
#
# [8 rows x 121 columns]

# %%
SmallSize = pd.concat([SmallSize1, SmallSize2])
SmallSize
# Out:
#        지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시          40㎡이하        -  ...  102.685641  103.629178  104.335195
# 6    강북지역          40㎡이하        -  ...  102.956232  103.834502  104.413468
# 12    도심권          40㎡이하        -  ...  101.330295  101.803374  102.111611
# 18    동북권          40㎡이하        -  ...  103.708387  104.816836  105.502076
# 24    서북권          40㎡이하        -  ...  101.103820  101.362431  101.717963
# 30   강남지역          40㎡이하        -  ...  102.470787  103.466051  104.272940
# 36    서남권          40㎡이하        -  ...  102.128339  103.087783  103.601847
# 42    동남권          40㎡이하        -  ...  102.888581  103.927709  105.094515
# 1   서울특별시  40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
# 7    강북지역  40㎡초과 ~ 60㎡이하  73.3718  ...  103.411192  104.281339  104.854077
# 13    도심권  40㎡초과 ~ 60㎡이하  72.5237  ...  102.346946  103.861402  105.284437
# ...

# %%
SmallSize = SmallSize.reset_index()
SmallSize.drop(columns=['index'], inplace=True)
SmallSize
# Out:
#        지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시          40㎡이하        -  ...  102.685641  103.629178  104.335195
# 1    강북지역          40㎡이하        -  ...  102.956232  103.834502  104.413468
# 2     도심권          40㎡이하        -  ...  101.330295  101.803374  102.111611
# 3     동북권          40㎡이하        -  ...  103.708387  104.816836  105.502076
# 4     서북권          40㎡이하        -  ...  101.103820  101.362431  101.717963
# 5    강남지역          40㎡이하        -  ...  102.470787  103.466051  104.272940
# 6     서남권          40㎡이하        -  ...  102.128339  103.087783  103.601847
# 7     동남권          40㎡이하        -  ...  102.888581  103.927709  105.094515
# 8   서울특별시  40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
# 9    강북지역  40㎡초과 ~ 60㎡이하  73.3718  ...  103.411192  104.281339  104.854077
# 10    도심권  40㎡초과 ~ 60㎡이하  72.5237  ...  102.346946  103.861402  105.284437
# ...

# %%
SmallSize.to_excel('/content/drive/MyDrive/data/전처리/소형평수.xlsx')

# %% [markdown]
# #### 중형 평수(60㎡초과 ~ 102㎡이하)

# %%
MSize = apc_data_2['규모'] == ('60㎡초과 ~ 85㎡이하')
MiddleSize1 = apc_data_2[MSize]

# %%
MSize = apc_data_2['규모'] == ('85㎡초과 ~ 102㎡이하')
MiddleSize2 = apc_data_2[MSize]

# %%
MiddleSize = pd.concat([MiddleSize1, MiddleSize2])

# %%
MiddleSize = MiddleSize.reset_index()
MiddleSize
# Out:
#     index     지역              규모  ...     2021-09     2021-10     2021-11
# 0       2  서울특별시   60㎡초과 ~ 85㎡이하  ...  102.537131  103.383135  104.017918
# 1       8   강북지역   60㎡초과 ~ 85㎡이하  ...  102.276796  103.044533  103.570107
# 2      14    도심권   60㎡초과 ~ 85㎡이하  ...  102.550503  103.725761  104.653339
# 3      20    동북권   60㎡초과 ~ 85㎡이하  ...  102.261944  102.865807  103.272829
# 4      26    서북권   60㎡초과 ~ 85㎡이하  ...  102.236327  103.368228  104.125716
# 5      32   강남지역   60㎡초과 ~ 85㎡이하  ...  102.764722  103.679354  104.410057
# 6      38    서남권   60㎡초과 ~ 85㎡이하  ...  102.403855  103.065587  103.568509
# 7      44    동남권   60㎡초과 ~ 85㎡이하  ...  103.226489  104.466895  105.492521
# 8       3  서울특별시  85㎡초과 ~ 102㎡이하  ...  102.627636  103.240619  103.891569
# 9       9   강북지역  85㎡초과 ~ 102㎡이하  ...  102.189724  102.882344  103.306783
# 10     15    도심권  85㎡초과 ~ 102㎡이하  ...  101.220377  102.385487  103.889845
# 11     21    동북권  85㎡초과 ~ 102㎡이하  ...  102.691187  103.218062  103.334423
# ...

# %%
MiddleSize.drop(columns=['index'], inplace=True)
MiddleSize.head(2)
# Out:
#       지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시  60㎡초과 ~ 85㎡이하  78.5747  ...  102.537131  103.383135  104.017918
# 1   강북지역  60㎡초과 ~ 85㎡이하  81.8605  ...  102.276796  103.044533  103.570107
#
# [2 rows x 121 columns]

# %%
MiddleSize.to_excel('/content/drive/MyDrive/data/전처리/중간평수.xlsx')

# %% [markdown]
# ####대형 평수(102㎡초과 ~)

# %%
LSize = apc_data_2['규모'] == ('102㎡초과 ~ 135㎡이하')
LargeSize1 = apc_data_2[LSize]

# %%
LSize = apc_data_2['규모'] == ('135㎡초과')
LargeSize2 = apc_data_2[LSize]

# %%
LargeSize = pd.concat([LargeSize1, LargeSize2])
LargeSize
# Out:
#        지역               규모  2012-01  ...     2021-09     2021-10     2021-11
# 4   서울특별시  102㎡초과 ~ 135㎡이하  87.6806  ...  102.145024  102.858093  103.381403
# 10   강북지역  102㎡초과 ~ 135㎡이하   92.252  ...  101.750645  102.371911  102.954339
# 16    도심권  102㎡초과 ~ 135㎡이하  91.2236  ...  102.128694  103.448787  104.355672
# 22    동북권  102㎡초과 ~ 135㎡이하  93.9505  ...  101.759636  102.161753  102.394490
# 28    서북권  102㎡초과 ~ 135㎡이하  88.2195  ...  101.495063  102.277162  103.604539
# 34   강남지역  102㎡초과 ~ 135㎡이하  84.5452  ...  102.432829  103.213159  103.693133
# 40    서남권  102㎡초과 ~ 135㎡이하  86.6554  ...  101.954837  102.714469  103.243507
# 46    동남권  102㎡초과 ~ 135㎡이하  82.7782  ...  102.860447  103.659364  104.095248
# 5   서울특별시           135㎡초과  93.5878  ...  102.298693  102.965753  103.608030
# 11   강북지역           135㎡초과  98.0224  ...  101.152074  101.479061  102.246492
# 17    도심권           135㎡초과  100.273  ...  101.670417  102.027503  102.663063
# ...

# %%
LargeSize = LargeSize.reset_index()
LargeSize.head(2)
# Out:
#    index     지역               규모  ...     2021-09     2021-10     2021-11
# 0      4  서울특별시  102㎡초과 ~ 135㎡이하  ...  102.145024  102.858093  103.381403
# 1     10   강북지역  102㎡초과 ~ 135㎡이하  ...  101.750645  102.371911  102.954339
#
# [2 rows x 122 columns]

# %%
LargeSize.drop(columns=['index'], inplace=True)
LargeSize.head(2)
# Out:
#       지역               규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시  102㎡초과 ~ 135㎡이하  87.6806  ...  102.145024  102.858093  103.381403
# 1   강북지역  102㎡초과 ~ 135㎡이하   92.252  ...  101.750645  102.371911  102.954339
#
# [2 rows x 121 columns]

# %%
LargeSize.to_excel('/content/drive/MyDrive/data/전처리/대형평수.xlsx')

# %% [markdown]
# ### 권역별 아파트 매매 지수

# %%
apc_data_2
# Out:
#       지 역               규모 2012년 01월  ...   2021년 09월   2021년 10월   2021년 11월
# 0   서울특별시            40㎡이하         -  ...  102.685641  103.629178  104.335195
# 1   서울특별시    40㎡초과 ~ 60㎡이하   71.8267  ...  103.197712  104.170438  104.789905
# 2   서울특별시    60㎡초과 ~ 85㎡이하   78.5747  ...  102.537131  103.383135  104.017918
# 3   서울특별시   85㎡초과 ~ 102㎡이하    80.531  ...  102.627636  103.240619  103.891569
# 4   서울특별시  102㎡초과 ~ 135㎡이하   87.6806  ...  102.145024  102.858093  103.381403
# 5   서울특별시           135㎡초과   93.5878  ...  102.298693  102.965753  103.608030
# 6    강북지역            40㎡이하         -  ...  102.956232  103.834502  104.413468
# 7    강북지역    40㎡초과 ~ 60㎡이하   73.3718  ...  103.411192  104.281339  104.854077
# 8    강북지역    60㎡초과 ~ 85㎡이하   81.8605  ...  102.276796  103.044533  103.570107
# 9    강북지역   85㎡초과 ~ 102㎡이하   85.7194  ...  102.189724  102.882344  103.306783
# 10   강북지역  102㎡초과 ~ 135㎡이하    92.252  ...  101.750645  102.371911  102.954339
# ...

# %% [markdown]
# #### 서울특별시

# %%
Seoul = apc_data_2['지역'] == '서울특별시'
Seoul = apc_data_2[Seoul]

# %%
Seoul.head(2)
# Out:
#       지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시          40㎡이하        -  ...  102.685641  103.629178  104.335195
# 1  서울특별시  40㎡초과 ~ 60㎡이하  71.8267  ...  103.197712  104.170438  104.789905
#
# [2 rows x 121 columns]

# %%
Seoul.to_excel('/content/drive/MyDrive/data/전처리/서울특별시.xlsx')

# %% [markdown]
# #### 강북지역

# %%
KangBuk = apc_data_2['지역'] == '강북지역'
KangBuk = apc_data_2[KangBuk] 
KangBuk.head(2)
# Out:
#      지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 6  강북지역          40㎡이하        -  ...  102.956232  103.834502  104.413468
# 7  강북지역  40㎡초과 ~ 60㎡이하  73.3718  ...  103.411192  104.281339  104.854077
#
# [2 rows x 121 columns]

# %%
KangBuk = KangBuk.reset_index()
KangBuk.head(2)
# Out:
#    index    지역             규모  ...     2021-09     2021-10     2021-11
# 0      6  강북지역          40㎡이하  ...  102.956232  103.834502  104.413468
# 1      7  강북지역  40㎡초과 ~ 60㎡이하  ...  103.411192  104.281339  104.854077
#
# [2 rows x 122 columns]

# %%
KangBuk.drop(columns='index', inplace=True)
KangBuk.head(2)
# Out:
#      지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  강북지역          40㎡이하        -  ...  102.956232  103.834502  104.413468
# 1  강북지역  40㎡초과 ~ 60㎡이하  73.3718  ...  103.411192  104.281339  104.854077
#
# [2 rows x 121 columns]

# %%
KangBuk.to_excel('/content/drive/MyDrive/data/전처리/강북지역.xlsx')

# %% [markdown]
# #### 도심권

# %%
DoSim = apc_data_2['지역'] == '도심권'
DoSim = apc_data_2[DoSim]
DoSim.head(2)
# Out:
#      지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 12  도심권          40㎡이하        -  ...  101.330295  101.803374  102.111611
# 13  도심권  40㎡초과 ~ 60㎡이하  72.5237  ...  102.346946  103.861402  105.284437
#
# [2 rows x 121 columns]

# %%
DoSim = DoSim.reset_index()
DoSim.drop(columns='index', inplace=True)
DoSim.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  도심권          40㎡이하        -  ...  101.330295  101.803374  102.111611
# 1  도심권  40㎡초과 ~ 60㎡이하  72.5237  ...  102.346946  103.861402  105.284437
#
# [2 rows x 121 columns]

# %%
DoSim.to_excel('/content/drive/MyDrive/data/전처리/도심권.xlsx')

# %% [markdown]
# ####동북권

# %%
DongBuk = apc_data_2['지역'] == '동북권'
DongBuk = apc_data_2[DongBuk]
DongBuk = DongBuk.reset_index()
DongBuk.drop(columns='index', inplace=True)
DongBuk.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  동북권          40㎡이하        -  ...  103.708387  104.816836  105.502076
# 1  동북권  40㎡초과 ~ 60㎡이하  74.2193  ...  103.625547  104.360768  104.848110
#
# [2 rows x 121 columns]

# %%
DongBuk.to_excel('/content/drive/MyDrive/data/전처리/동북권.xlsx')

# %% [markdown]
# ####서북권

# %%
SuBuk = apc_data_2['지역'] == '서북권'
SuBuk = apc_data_2[SuBuk]
SuBuk = SuBuk.reset_index()
SuBuk.drop(columns='index', inplace=True)
SuBuk.head(2)
# Out:
#     지역             규모  2012-01  ...    2021-09     2021-10     2021-11
# 0  서북권          40㎡이하        -  ...  101.10382  101.362431  101.717963
# 1  서북권  40㎡초과 ~ 60㎡이하  69.7842  ...  102.87623  104.091175  104.727760
#
# [2 rows x 121 columns]

# %%
SuBuk.to_excel('/content/drive/MyDrive/data/전처리/서북권.xlsx')

# %% [markdown]
# ####강남지역

# %%
KangNam = apc_data_2['지역'] == '강남지역'
KangNam = apc_data_2[KangNam]
KangNam = KangNam.reset_index()
KangNam.drop(columns='index', inplace=True)
KangNam.head(2)
# Out:
#      지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  강남지역          40㎡이하        -  ...  102.470787  103.466051  104.272940
# 1  강남지역  40㎡초과 ~ 60㎡이하  70.1421  ...  102.944743  104.038877  104.713742
#
# [2 rows x 121 columns]

# %%
KangNam.to_excel('/content/drive/MyDrive/data/전처리/강남지역.xlsx')

# %% [markdown]
# ####서남권

# %%
SuNam = apc_data_2['지역'] == '서남권'
SuNam = apc_data_2[SuNam]
SuNam = SuNam.reset_index()
SuNam.drop(columns='index', inplace=True)
SuNam.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서남권          40㎡이하        -  ...  102.128339  103.087783  103.601847
# 1  서남권  40㎡초과 ~ 60㎡이하  72.0779  ...  102.929615  103.851393  104.408653
#
# [2 rows x 121 columns]

# %%
SuNam.to_excel('/content/drive/MyDrive/data/전처리/서남권.xlsx')

# %% [markdown]
# ####동남권

# %%
DongNam = apc_data_2['지역'] == '동남권'
DongNam = apc_data_2[DongNam]
DongNam = DongNam.reset_index()
DongNam.drop(columns='index', inplace=True)
DongNam.head(2)
# Out:
#     지역             규모 2012-01  ...     2021-09     2021-10     2021-11
# 0  동남권          40㎡이하       -  ...  102.888581  103.927709  105.094515
# 1  동남권  40㎡초과 ~ 60㎡이하  67.351  ...  102.969001  104.340182  105.204758
#
# [2 rows x 121 columns]

# %%
DongNam.to_excel('/content/drive/MyDrive/data/전처리/동남권.xlsx')

# %% [markdown]
# # 규모별 아파트 전세 가격지수

# %%
apc_data_3 = pd.read_excel('/content/drive/MyDrive/data/신규자료/규모별_전세가격지수_아파트.xlsx')
apc_data_3.head(2)
# Out:
#   지 역             규모 2012년 01월  ...   2021년 09월   2021년 10월   2021년 11월
# 0  서울          40㎡이하         -  ...  101.246054  101.722627  101.873381
# 1  서울  40㎡초과 ~ 60㎡이하   68.7632  ...  102.422481  102.984986  103.555631
#
# [2 rows x 121 columns]

# %%
names = []
for name in apc_data_3.columns[2:]:
  name = pd.to_datetime(name, format='%Y년 %m월')
  names.append(name.strftime('%Y-%m'))
print(names)
# Out:
# ['2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-0
# ...

# %%
names.insert(0, '규모')

# %%
names.insert(0, '지역')

# %%
apc_data_3.columns = names
apc_data_3.head(2)
# Out:
#    지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울          40㎡이하        -  ...  101.246054  101.722627  101.873381
# 1  서울  40㎡초과 ~ 60㎡이하  68.7632  ...  102.422481  102.984986  103.555631
#
# [2 rows x 121 columns]

# %%
apc_data_3.loc[apc_data_3['지역'] == '서울', '지역'] = '서울특별시'
apc_data_3.head(2)
# Out:
#       지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시          40㎡이하        -  ...  101.246054  101.722627  101.873381
# 1  서울특별시  40㎡초과 ~ 60㎡이하  68.7632  ...  102.422481  102.984986  103.555631
#
# [2 rows x 121 columns]

# %% [markdown]
# ##  도심권별 아파트 전세 지수

# %% [markdown]
# ### 소형 평수(1㎡ ~ 60㎡이하)

# %%
SSize = apc_data_3['규모'] == '40㎡이하'
SmallSize1 = apc_data_3[SSize]

# %%
SmallSize1
# Out:
#        지역     규모 2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시  40㎡이하       -  ...  101.246054  101.722627  101.873381
# 6    강북지역  40㎡이하       -  ...  100.782559  101.212727  101.490469
# 12    도심권  40㎡이하       -  ...  100.559619  100.792313  101.152068
# 18    동북권  40㎡이하       -  ...  100.916818  101.473499  101.716115
# 24    서북권  40㎡이하       -  ...  100.397518  100.458042  100.818451
# 30   강남지역  40㎡이하       -  ...  101.616471  102.130289  102.179171
# 36    서남권  40㎡이하       -  ...  100.881345  100.836927  100.626303
# 42    동남권  40㎡이하       -  ...  102.517236  103.724735  104.098994
#
# [8 rows x 121 columns]

# %%
SSize = apc_data_3['규모'] == '40㎡초과 ~ 60㎡이하'
SmallSize2 = apc_data_3[SSize]

# %%
SmallSize = pd.concat([SmallSize1, SmallSize2])
SmallSize
# Out:
#        지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시          40㎡이하        -  ...  101.246054  101.722627  101.873381
# 6    강북지역          40㎡이하        -  ...  100.782559  101.212727  101.490469
# 12    도심권          40㎡이하        -  ...  100.559619  100.792313  101.152068
# 18    동북권          40㎡이하        -  ...  100.916818  101.473499  101.716115
# 24    서북권          40㎡이하        -  ...  100.397518  100.458042  100.818451
# 30   강남지역          40㎡이하        -  ...  101.616471  102.130289  102.179171
# 36    서남권          40㎡이하        -  ...  100.881345  100.836927  100.626303
# 42    동남권          40㎡이하        -  ...  102.517236  103.724735  104.098994
# 1   서울특별시  40㎡초과 ~ 60㎡이하  68.7632  ...  102.422481  102.984986  103.555631
# 7    강북지역  40㎡초과 ~ 60㎡이하  68.0862  ...  102.231871  102.776060  103.258619
# 13    도심권  40㎡초과 ~ 60㎡이하  67.5395  ...  102.195972  103.526755  104.263852
# ...

# %%
SmallSize = SmallSize.reset_index()
SmallSize.drop(columns=['index'], inplace=True)
SmallSize
# Out:
#        지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시          40㎡이하        -  ...  101.246054  101.722627  101.873381
# 1    강북지역          40㎡이하        -  ...  100.782559  101.212727  101.490469
# 2     도심권          40㎡이하        -  ...  100.559619  100.792313  101.152068
# 3     동북권          40㎡이하        -  ...  100.916818  101.473499  101.716115
# 4     서북권          40㎡이하        -  ...  100.397518  100.458042  100.818451
# 5    강남지역          40㎡이하        -  ...  101.616471  102.130289  102.179171
# 6     서남권          40㎡이하        -  ...  100.881345  100.836927  100.626303
# 7     동남권          40㎡이하        -  ...  102.517236  103.724735  104.098994
# 8   서울특별시  40㎡초과 ~ 60㎡이하  68.7632  ...  102.422481  102.984986  103.555631
# 9    강북지역  40㎡초과 ~ 60㎡이하  68.0862  ...  102.231871  102.776060  103.258619
# 10    도심권  40㎡초과 ~ 60㎡이하  67.5395  ...  102.195972  103.526755  104.263852
# ...

# %%
SmallSize.to_excel('/content/drive/MyDrive/data/전처리/소형평수(전세).xlsx')

# %% [markdown]
# ###중형 평수(60㎡초과 ~ 102㎡이하)

# %%
MSize = apc_data_3['규모'] == ('60㎡초과 ~ 85㎡이하')
MiddleSize1 = apc_data_3[MSize]

# %%
MSize = apc_data_3['규모'] == ('85㎡초과 ~ 102㎡이하')
MiddleSize2 = apc_data_3[MSize]

# %%
MiddleSize = pd.concat([MiddleSize1, MiddleSize2])

# %%
MiddleSize = MiddleSize.reset_index()
MiddleSize
# Out:
#     index     지역              규모  ...     2021-09     2021-10     2021-11
# 0       2  서울특별시   60㎡초과 ~ 85㎡이하  ...  102.125441  102.900028  103.372326
# 1       8   강북지역   60㎡초과 ~ 85㎡이하  ...  102.049296  102.790311  103.298913
# 2      14    도심권   60㎡초과 ~ 85㎡이하  ...  102.361129  103.372260  104.131439
# 3      20    동북권   60㎡초과 ~ 85㎡이하  ...  102.044158  102.712099  103.136092
# 4      26    서북권   60㎡초과 ~ 85㎡이하  ...  101.968062  102.843786  103.528206
# 5      32   강남지역   60㎡초과 ~ 85㎡이하  ...  102.191898  102.995813  103.436395
# 6      38    서남권   60㎡초과 ~ 85㎡이하  ...  102.073042  102.853728  103.369184
# 7      44    동남권   60㎡초과 ~ 85㎡이하  ...  102.343580  103.177184  103.522119
# 8       3  서울특별시  85㎡초과 ~ 102㎡이하  ...  102.005110  102.439778  102.856025
# 9       9   강북지역  85㎡초과 ~ 102㎡이하  ...  101.835183  102.088582  102.618718
# 10     15    도심권  85㎡초과 ~ 102㎡이하  ...  102.179455  103.366084  103.322624
# 11     21    동북권  85㎡초과 ~ 102㎡이하  ...  102.137909  102.197654  103.082683
# ...

# %%
MiddleSize.drop(columns='index', inplace=True)
MiddleSize.head(2)
# Out:
#       지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시  60㎡초과 ~ 85㎡이하  66.7877  ...  102.125441  102.900028  103.372326
# 1   강북지역  60㎡초과 ~ 85㎡이하  68.8329  ...  102.049296  102.790311  103.298913
#
# [2 rows x 121 columns]

# %%
MiddleSize.to_excel('/content/drive/MyDrive/data/전처리/중형평수(전세).xlsx')

# %% [markdown]
# ###대형 평수(102㎡초과 ~)

# %%
LSize = apc_data_3['규모'] == ('102㎡초과 ~ 135㎡이하')
LargeSize1 = apc_data_3[LSize]

# %%
LSize = apc_data_3['규모'] == ('135㎡초과')
LargeSize2 = apc_data_3[LSize]

# %%
LargeSize = pd.concat([LargeSize1, LargeSize2])
LargeSize
# Out:
#        지역               규모  2012-01  ...     2021-09     2021-10     2021-11
# 4   서울특별시  102㎡초과 ~ 135㎡이하  72.5228  ...  101.835413  102.466281  103.067958
# 10   강북지역  102㎡초과 ~ 135㎡이하  74.0518  ...  101.482896  102.155308  102.799147
# 16    도심권  102㎡초과 ~ 135㎡이하  78.3317  ...  101.933401  102.664044  103.711213
# 22    동북권  102㎡초과 ~ 135㎡이하  72.0803  ...  101.478621  102.127112  102.692452
# 28    서북권  102㎡초과 ~ 135㎡이하   77.279  ...  101.218526  101.919323  102.527499
# 34   강남지역  102㎡초과 ~ 135㎡이하  71.4391  ...  102.092580  102.693057  103.263914
# 40    서남권  102㎡초과 ~ 135㎡이하  66.5933  ...  102.270199  102.833307  103.155404
# 46    동남권  102㎡초과 ~ 135㎡이하  75.8336  ...  101.934641  102.568302  103.360656
# 5   서울특별시           135㎡초과  75.7974  ...  101.782101  102.112588  102.360569
# 11   강북지역           135㎡초과  80.2328  ...  101.374984  101.530332  101.992308
# 17    도심권           135㎡초과  80.9929  ...  101.140459  101.275642  101.544069
# ...

# %%
LargeSize = LargeSize.reset_index()
LargeSize.drop(columns=['index'], inplace=True)
LargeSize
# Out:
#        지역               규모  2012-01  ...     2021-09     2021-10     2021-11
# 0   서울특별시  102㎡초과 ~ 135㎡이하  72.5228  ...  101.835413  102.466281  103.067958
# 1    강북지역  102㎡초과 ~ 135㎡이하  74.0518  ...  101.482896  102.155308  102.799147
# 2     도심권  102㎡초과 ~ 135㎡이하  78.3317  ...  101.933401  102.664044  103.711213
# 3     동북권  102㎡초과 ~ 135㎡이하  72.0803  ...  101.478621  102.127112  102.692452
# 4     서북권  102㎡초과 ~ 135㎡이하   77.279  ...  101.218526  101.919323  102.527499
# 5    강남지역  102㎡초과 ~ 135㎡이하  71.4391  ...  102.092580  102.693057  103.263914
# 6     서남권  102㎡초과 ~ 135㎡이하  66.5933  ...  102.270199  102.833307  103.155404
# 7     동남권  102㎡초과 ~ 135㎡이하  75.8336  ...  101.934641  102.568302  103.360656
# 8   서울특별시           135㎡초과  75.7974  ...  101.782101  102.112588  102.360569
# 9    강북지역           135㎡초과  80.2328  ...  101.374984  101.530332  101.992308
# 10    도심권           135㎡초과  80.9929  ...  101.140459  101.275642  101.544069
# ...

# %%
LargeSize.to_excel('/content/drive/MyDrive/data/전처리/대형평수(전세).xlsx')

# %% [markdown]
# ##권역별 아파트 전세 지수

# %%
apc_data_3
# Out:
#       지 역               규모 2012년 01월  ...   2021년 09월   2021년 10월   2021년 11월
# 0   서울특별시            40㎡이하         -  ...  101.246054  101.722627  101.873381
# 1   서울특별시    40㎡초과 ~ 60㎡이하   68.7632  ...  102.422481  102.984986  103.555631
# 2   서울특별시    60㎡초과 ~ 85㎡이하   66.7877  ...  102.125441  102.900028  103.372326
# 3   서울특별시   85㎡초과 ~ 102㎡이하   73.2592  ...  102.005110  102.439778  102.856025
# 4   서울특별시  102㎡초과 ~ 135㎡이하   72.5228  ...  101.835413  102.466281  103.067958
# 5   서울특별시           135㎡초과   75.7974  ...  101.782101  102.112588  102.360569
# 6    강북지역            40㎡이하         -  ...  100.782559  101.212727  101.490469
# 7    강북지역    40㎡초과 ~ 60㎡이하   68.0862  ...  102.231871  102.776060  103.258619
# 8    강북지역    60㎡초과 ~ 85㎡이하   68.8329  ...  102.049296  102.790311  103.298913
# 9    강북지역   85㎡초과 ~ 102㎡이하   73.8685  ...  101.835183  102.088582  102.618718
# 10   강북지역  102㎡초과 ~ 135㎡이하   74.0518  ...  101.482896  102.155308  102.799147
# ...

# %% [markdown]
# ###서울특별시

# %%
Seoul = apc_data_3['지역'] == '서울특별시'
Seoul = apc_data_3[Seoul]

# %%
Seoul.head(2)
# Out:
#       지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서울특별시          40㎡이하        -  ...  101.246054  101.722627  101.873381
# 1  서울특별시  40㎡초과 ~ 60㎡이하  68.7632  ...  102.422481  102.984986  103.555631
#
# [2 rows x 121 columns]

# %%
Seoul.to_excel('/content/drive/MyDrive/data/전처리/서울특별시(전세).xlsx')

# %% [markdown]
# ###강북지역

# %%
KangBuk = apc_data_3['지역'] == '강북지역'
KangBuk = apc_data_3[KangBuk]
KangBuk = KangBuk.reset_index()
KangBuk.drop(columns='index', inplace=True)
KangBuk.head(2)
# Out:
#      지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  강북지역          40㎡이하        -  ...  100.782559  101.212727  101.490469
# 1  강북지역  40㎡초과 ~ 60㎡이하  68.0862  ...  102.231871  102.776060  103.258619
#
# [2 rows x 121 columns]

# %%
KangBuk.to_excel('/content/drive/MyDrive/data/전처리/강북지역(전세).xlsx')

# %% [markdown]
# ###도심권

# %%
DoSim = apc_data_3['지역'] == '도심권'
DoSim = apc_data_3[DoSim]
DoSim = DoSim.reset_index()
DoSim.drop(columns='index', inplace=True)
DoSim.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  도심권          40㎡이하        -  ...  100.559619  100.792313  101.152068
# 1  도심권  40㎡초과 ~ 60㎡이하  67.5395  ...  102.195972  103.526755  104.263852
#
# [2 rows x 121 columns]

# %%
DoSim.to_excel('/content/drive/MyDrive/data/전처리/도심권(전세).xlsx')

# %% [markdown]
# ###동북권

# %%
DongBuk = apc_data_3['지역'] == '동북권'
DongBuk = apc_data_3[DongBuk]
DongBuk = DongBuk.reset_index()
DongBuk.drop(columns='index', inplace=True)
DongBuk.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  동북권          40㎡이하        -  ...  100.916818  101.473499  101.716115
# 1  동북권  40㎡초과 ~ 60㎡이하  68.3053  ...  102.248791  102.625874  103.043149
#
# [2 rows x 121 columns]

# %%
DongBuk.to_excel('/content/drive/MyDrive/data/전처리/동북권(전세).xlsx')

# %% [markdown]
# ###서북권

# %%
SuBuk = apc_data_3['지역'] == '서북권'
SuBuk = apc_data_3[SuBuk]
SuBuk = SuBuk.reset_index()
SuBuk.drop(columns='index', inplace=True)
SuBuk.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서북권          40㎡이하        -  ...  100.397518  100.458042  100.818451
# 1  서북권  40㎡초과 ~ 60㎡이하  67.2898  ...  102.172316  103.154227  103.827744
#
# [2 rows x 121 columns]

# %%
SuBuk.to_excel('/content/drive/MyDrive/data/전처리/서북권(전세).xlsx')

# %% [markdown]
# ###강남지역

# %%
KangNam = apc_data_3['지역'] == '강남지역'
KangNam = apc_data_3[KangNam]
KangNam = KangNam.reset_index()
KangNam.drop(columns='index', inplace=True)
KangNam.head(2)
# Out:
#      지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  강남지역          40㎡이하        -  ...  101.616471  102.130289  102.179171
# 1  강남지역  40㎡초과 ~ 60㎡이하  69.4988  ...  102.649323  103.233671  103.909491
#
# [2 rows x 121 columns]

# %%
KangNam.to_excel('/content/drive/MyDrive/data/전처리/강남권(전세).xlsx')

# %% [markdown]
# ###서남권

# %%
SuNam = apc_data_3['지역'] == '서남권'
SuNam = apc_data_3[SuNam]
SuNam = SuNam.reset_index()
SuNam.drop(columns='index', inplace=True)
SuNam.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  서남권          40㎡이하        -  ...  100.881345  100.836927  100.626303
# 1  서남권  40㎡초과 ~ 60㎡이하  66.3092  ...  102.481223  103.003944  103.681020
#
# [2 rows x 121 columns]

# %%
SuNam.to_excel('/content/drive/MyDrive/data/전처리/서남권(전세).xlsx')

# %% [markdown]
# ###동남권

# %%
DongNam = apc_data_3['지역'] == '동남권'
DongNam = apc_data_3[DongNam]
DongNam = DongNam.reset_index()
DongNam.drop(columns='index', inplace=True)
DongNam.head(2)
# Out:
#     지역             규모  2012-01  ...     2021-09     2021-10     2021-11
# 0  동남권          40㎡이하        -  ...  102.517236  103.724735  104.098994
# 1  동남권  40㎡초과 ~ 60㎡이하  73.7974  ...  102.919416  103.603068  104.276853
#
# [2 rows x 121 columns]

# %%
DongNam.to_excel('/content/drive/MyDrive/data/전처리/동남권(전세).xlsx')

# %% [markdown]
# # 규모별 아파트 월세 가격지수

# %%
apc_data_4 = pd.read_excel('/content/drive/MyDrive/data/신규자료/규모별_월세가격지수_아파트.xlsx')
apc_data_4
# Out:
#      지 역               규모 2015년 06월  ...   2021년 09월   2021년 10월   2021년 11월
# 0     서울            40㎡이하         -  ...  101.047853  101.180134  101.515163
# 1     서울    40㎡초과 ~ 60㎡이하   97.3609  ...  100.944004  101.228495  101.604659
# 2     서울    60㎡초과 ~ 85㎡이하   98.3437  ...  100.638311  101.025692  101.298798
# 3     서울   85㎡초과 ~ 102㎡이하   99.5987  ...   99.949993  100.054956  100.576871
# 4     서울  102㎡초과 ~ 135㎡이하   98.9426  ...  100.673252  101.082255  101.321255
# 5     서울           135㎡초과    97.923  ...  100.729591  100.928504  101.045863
# 6   강북지역            40㎡이하         -  ...  101.002252  101.008416  101.278531
# 7   강북지역    40㎡초과 ~ 60㎡이하   97.7149  ...  100.899859  101.204239  101.658200
# 8   강북지역    60㎡초과 ~ 85㎡이하   98.6221  ...  100.551682  100.940793  101.121064
# 9   강북지역   85㎡초과 ~ 102㎡이하   98.1988  ...   99.366154   99.414625  100.565071
# 10  강북지역  102㎡초과 ~ 135㎡이하   99.0647  ...  100.397437  100.777631  101.158889
# ...

# %%
names = []
for name in apc_data_4.columns[2:]:
  name = pd.to_datetime(name, format='%Y년 %m월')
  names.append(name.strftime('%Y-%m'))
print(names)
# Out:
# ['2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09', '2021-10', '2021-11']

# %%
names.insert(0, '규모')

# %%
names.insert(0, '지역')

# %%
apc_data_4.columns = names
apc_data_4.head(2)
# Out:
#    지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  서울          40㎡이하        -  ...  101.047853  101.180134  101.515163
# 1  서울  40㎡초과 ~ 60㎡이하  97.3609  ...  100.944004  101.228495  101.604659
#
# [2 rows x 80 columns]

# %%
apc_data_4.loc[apc_data_4['지역'] == '서울', '지역'] = '서울특별시'
apc_data_4.head(2)
# Out:
#       지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  서울특별시          40㎡이하        -  ...  101.047853  101.180134  101.515163
# 1  서울특별시  40㎡초과 ~ 60㎡이하  97.3609  ...  100.944004  101.228495  101.604659
#
# [2 rows x 80 columns]

# %% [markdown]
# ##도심권별 아파트 월세 지수

# %% [markdown]
# ###소형 평수(1㎡ ~ 60㎡이하)

# %%
SSize = apc_data_4['규모'] == '40㎡이하'
SmallSize1 = apc_data_4[SSize]

# %%
SSize = apc_data_4['규모'] == '40㎡초과 ~ 60㎡이하'
SmallSize2 = apc_data_4[SSize]

# %%
SmallSize = pd.concat([SmallSize1, SmallSize2])
SmallSize
# Out:
#        지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0   서울특별시          40㎡이하        -  ...  101.047853  101.180134  101.515163
# 6    강북지역          40㎡이하        -  ...  101.002252  101.008416  101.278531
# 12    도심권          40㎡이하        -  ...  100.634862  100.826310  101.578970
# 18    동북권          40㎡이하        -  ...  101.077890  101.010227  101.201429
# 24    서북권          40㎡이하        -  ...  100.961204  101.133756  101.375387
# 30   강남지역          40㎡이하        -  ...  101.084162  101.317011  101.703893
# 36    서남권          40㎡이하        -  ...  100.998244  101.150859  101.550896
# 42    동남권          40㎡이하        -  ...  101.188694  101.519338  101.890172
# 1   서울특별시  40㎡초과 ~ 60㎡이하  97.3609  ...  100.944004  101.228495  101.604659
# 7    강북지역  40㎡초과 ~ 60㎡이하  97.7149  ...  100.899859  101.204239  101.658200
# 13    도심권  40㎡초과 ~ 60㎡이하  97.8143  ...  101.385102  101.751196  102.086884
# ...

# %%
SmallSize = SmallSize.reset_index()
SmallSize.drop(columns=['index'], inplace=True)
SmallSize
# Out:
#        지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0   서울특별시          40㎡이하        -  ...  101.047853  101.180134  101.515163
# 1    강북지역          40㎡이하        -  ...  101.002252  101.008416  101.278531
# 2     도심권          40㎡이하        -  ...  100.634862  100.826310  101.578970
# 3     동북권          40㎡이하        -  ...  101.077890  101.010227  101.201429
# 4     서북권          40㎡이하        -  ...  100.961204  101.133756  101.375387
# 5    강남지역          40㎡이하        -  ...  101.084162  101.317011  101.703893
# 6     서남권          40㎡이하        -  ...  100.998244  101.150859  101.550896
# 7     동남권          40㎡이하        -  ...  101.188694  101.519338  101.890172
# 8   서울특별시  40㎡초과 ~ 60㎡이하  97.3609  ...  100.944004  101.228495  101.604659
# 9    강북지역  40㎡초과 ~ 60㎡이하  97.7149  ...  100.899859  101.204239  101.658200
# 10    도심권  40㎡초과 ~ 60㎡이하  97.8143  ...  101.385102  101.751196  102.086884
# ...

# %%
SmallSize.to_excel('/content/drive/MyDrive/data/전처리/소형평수(월세).xlsx')

# %% [markdown]
# ###중형 평수(60㎡초과 ~ 102㎡이하)

# %%
MSize = apc_data_4['규모'] == ('60㎡초과 ~ 85㎡이하')
MiddleSize1 = apc_data_4[MSize]

# %%
MSize = apc_data_4['규모'] == ('85㎡초과 ~ 102㎡이하')
MiddleSize2 = apc_data_4[MSize]

# %%
MiddleSize = pd.concat([MiddleSize1, MiddleSize2])

# %%
MiddleSize = MiddleSize.reset_index()
MiddleSize.drop(columns='index', inplace=True)
MiddleSize.head(2)
# Out:
#       지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  서울특별시  60㎡초과 ~ 85㎡이하  98.3437  ...  100.638311  101.025692  101.298798
# 1   강북지역  60㎡초과 ~ 85㎡이하  98.6221  ...  100.551682  100.940793  101.121064
#
# [2 rows x 80 columns]

# %%
MiddleSize.to_excel('/content/drive/MyDrive/data/전처리/중형평수(월세).xlsx')

# %% [markdown]
# ###대형 평수(102㎡초과 ~)

# %%
LSize = apc_data_4['규모'] == ('102㎡초과 ~ 135㎡이하')
LargeSize1 = apc_data_4[LSize]

# %%
LSize = apc_data_4['규모'] == ('135㎡초과')
LargeSize2 = apc_data_4[LSize]

# %%
LargeSize = pd.concat([LargeSize1, LargeSize2])
LargeSize
# Out:
#        지역               규모  2015-06  ...     2021-09     2021-10     2021-11
# 4   서울특별시  102㎡초과 ~ 135㎡이하  98.9426  ...  100.673252  101.082255  101.321255
# 10   강북지역  102㎡초과 ~ 135㎡이하  99.0647  ...  100.397437  100.777631  101.158889
# 16    도심권  102㎡초과 ~ 135㎡이하  99.0431  ...   99.943384  100.341078  100.574232
# 22    동북권  102㎡초과 ~ 135㎡이하  98.9704  ...  100.604919  100.999371  101.363762
# 28    서북권  102㎡초과 ~ 135㎡이하  99.5038  ...  100.122370  100.453803  100.971235
# 34   강남지역  102㎡초과 ~ 135㎡이하  98.8524  ...  100.874338  101.304397  101.439513
# 40    서남권  102㎡초과 ~ 135㎡이하  98.6116  ...  100.542459  100.860864  101.043910
# 46    동남권  102㎡초과 ~ 135㎡이하  99.0522  ...  101.170854  101.701079  101.793168
# 5   서울특별시           135㎡초과   97.923  ...  100.729591  100.928504  101.045863
# 11   강북지역           135㎡초과  98.2798  ...  100.884392  101.065536  101.025911
# 17    도심권           135㎡초과  97.6501  ...  100.562257  100.717289  100.819663
# ...

# %%
LargeSize = LargeSize.reset_index()
LargeSize.drop(columns=['index'], inplace=True)
LargeSize
# Out:
#        지역               규모  2015-06  ...     2021-09     2021-10     2021-11
# 0   서울특별시  102㎡초과 ~ 135㎡이하  98.9426  ...  100.673252  101.082255  101.321255
# 1    강북지역  102㎡초과 ~ 135㎡이하  99.0647  ...  100.397437  100.777631  101.158889
# 2     도심권  102㎡초과 ~ 135㎡이하  99.0431  ...   99.943384  100.341078  100.574232
# 3     동북권  102㎡초과 ~ 135㎡이하  98.9704  ...  100.604919  100.999371  101.363762
# 4     서북권  102㎡초과 ~ 135㎡이하  99.5038  ...  100.122370  100.453803  100.971235
# 5    강남지역  102㎡초과 ~ 135㎡이하  98.8524  ...  100.874338  101.304397  101.439513
# 6     서남권  102㎡초과 ~ 135㎡이하  98.6116  ...  100.542459  100.860864  101.043910
# 7     동남권  102㎡초과 ~ 135㎡이하  99.0522  ...  101.170854  101.701079  101.793168
# 8   서울특별시           135㎡초과   97.923  ...  100.729591  100.928504  101.045863
# 9    강북지역           135㎡초과  98.2798  ...  100.884392  101.065536  101.025911
# 10    도심권           135㎡초과  97.6501  ...  100.562257  100.717289  100.819663
# ...

# %%
LargeSize.to_excel('/content/drive/MyDrive/data/전처리/대형평수(월세).xlsx')

# %% [markdown]
# ##권역별 아파트 전세지수

# %% [markdown]
# ###서울특별시

# %%
Seoul = apc_data_4['지역'] == '서울특별시'
Seoul = apc_data_4[Seoul]
Seoul
# Out:
#       지역               규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  서울특별시            40㎡이하        -  ...  101.047853  101.180134  101.515163
# 1  서울특별시    40㎡초과 ~ 60㎡이하  97.3609  ...  100.944004  101.228495  101.604659
# 2  서울특별시    60㎡초과 ~ 85㎡이하  98.3437  ...  100.638311  101.025692  101.298798
# 3  서울특별시   85㎡초과 ~ 102㎡이하  99.5987  ...   99.949993  100.054956  100.576871
# 4  서울특별시  102㎡초과 ~ 135㎡이하  98.9426  ...  100.673252  101.082255  101.321255
# 5  서울특별시           135㎡초과   97.923  ...  100.729591  100.928504  101.045863
#
# [6 rows x 80 columns]

# %%
Seoul.to_excel('/content/drive/MyDrive/data/전처리/서울특별시(월세).xlsx')

# %% [markdown]
# ###강북지역

# %%
KangBuk = apc_data_4['지역'] == '강북지역'
KangBuk = apc_data_4[KangBuk]
KangBuk = KangBuk.reset_index()
KangBuk.drop(columns='index', inplace=True)
KangBuk.head(2)
# Out:
#      지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  강북지역          40㎡이하        -  ...  101.002252  101.008416  101.278531
# 1  강북지역  40㎡초과 ~ 60㎡이하  97.7149  ...  100.899859  101.204239  101.658200
#
# [2 rows x 80 columns]

# %%
KangBuk.to_excel('/content/drive/MyDrive/data/전처리/강북지역(월세).xlsx')

# %% [markdown]
# ###도심권

# %%
DoSim = apc_data_4['지역'] == '도심권'
DoSim = apc_data_4[DoSim]
DoSim = DoSim.reset_index()
DoSim.drop(columns='index', inplace=True)
DoSim.head(2)
# Out:
#     지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  도심권          40㎡이하        -  ...  100.634862  100.826310  101.578970
# 1  도심권  40㎡초과 ~ 60㎡이하  97.8143  ...  101.385102  101.751196  102.086884
#
# [2 rows x 80 columns]

# %%
DoSim.to_excel('/content/drive/MyDrive/data/전처리/도심권(월세).xlsx')

# %% [markdown]
# ###동북권

# %%
DongBuk = apc_data_4['지역'] == '동북권'
DongBuk = apc_data_4[DongBuk]
DongBuk = DongBuk.reset_index()
DongBuk.drop(columns='index', inplace=True)
DongBuk.head(2)
# Out:
#     지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  동북권          40㎡이하        -  ...  101.077890  101.010227  101.201429
# 1  동북권  40㎡초과 ~ 60㎡이하  97.9145  ...  100.979119  101.312241  101.765388
#
# [2 rows x 80 columns]

# %%
DongBuk.to_excel('/content/drive/MyDrive/data/전처리/동북권(월세).xlsx')

# %% [markdown]
# ###서북권

# %%
SuBuk = apc_data_4['지역'] == '서북권'
SuBuk = apc_data_4[SuBuk]
SuBuk = SuBuk.reset_index()
SuBuk.drop(columns='index', inplace=True)
SuBuk.head(2)
# Out:
#     지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  서북권          40㎡이하        -  ...  100.961204  101.133756  101.375387
# 1  서북권  40㎡초과 ~ 60㎡이하  96.7788  ...  100.391525  100.552353  101.051127
#
# [2 rows x 80 columns]

# %%
SuBuk.to_excel('/content/drive/MyDrive/data/전처리/서북권(월세).xlsx')

# %% [markdown]
# ###강남지역

# %%
KangNam = apc_data_4['지역'] == '강남지역'
KangNam = apc_data_4[KangNam]
KangNam = KangNam.reset_index()
KangNam.drop(columns='index', inplace=True)
KangNam.head(2)
# Out:
#      지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  강남지역          40㎡이하        -  ...  101.084162  101.317011  101.703893
# 1  강남지역  40㎡초과 ~ 60㎡이하  96.9749  ...  100.996459  101.257310  101.541108
#
# [2 rows x 80 columns]

# %%
KangNam.to_excel('/content/drive/MyDrive/data/전처리/강남권(월세).xlsx')

# %% [markdown]
# ###서남권

# %%
SuNam = apc_data_4['지역'] == '서남권'
SuNam = apc_data_4[SuNam]
SuNam = SuNam.reset_index()
SuNam.drop(columns='index', inplace=True)
SuNam.head(2)
# Out:
#     지역             규모  2015-06  ...     2021-09     2021-10     2021-11
# 0  서남권          40㎡이하        -  ...  100.998244  101.150859  101.550896
# 1  서남권  40㎡초과 ~ 60㎡이하  96.8277  ...  100.599194  100.575036  100.620033
#
# [2 rows x 80 columns]

# %%
SuNam.to_excel('/content/drive/MyDrive/data/전처리/서남권(월세).xlsx')

# %% [markdown]
# ###동남권

# %%
DongNam = apc_data_4['지역'] == '동남권'
DongNam = apc_data_4[DongNam]
DongNam = DongNam.reset_index()
DongNam.drop(columns='index', inplace=True)
DongNam.head(2)
# Out:
#     지역             규모 2015-06  ...     2021-09     2021-10     2021-11
# 0  동남권          40㎡이하       -  ...  101.188694  101.519338  101.890172
# 1  동남권  40㎡초과 ~ 60㎡이하  97.031  ...  101.636679  102.360886  103.035514
#
# [2 rows x 80 columns]

# %%
DongNam.to_excel('/content/drive/MyDrive/data/전처리/동남권(월세).xlsx')

# %% [markdown]
# # 자료 재구성

# %%
apc_data_2 = apc_data_2.set_index(keys=['지역', '규모']).swapaxes(axis1=0, axis2=1)
apc_data_2
# Out:
# 지역         서울특별시                ...             동남권
# 규모         40㎡이하 40㎡초과 ~ 60㎡이하  ... 102㎡초과 ~ 135㎡이하   135㎡초과
# 2012-01        -       71.8267  ...         82.7782  90.4809
# 2012-02        -       71.7416  ...         82.0498  89.6516
# 2012-03        -       71.4696  ...         81.4541  89.1133
# 2012-04        -       71.1394  ...         81.1335  87.9396
# 2012-05        -       70.7402  ...         80.5968  87.4848
# ...          ...           ...  ...             ...      ...
# 2021-07   100.76       101.014  ...         100.984  100.864
# 2021-08  101.771       102.149  ...         101.872  101.685
# 2021-09  102.686       103.198  ...          102.86  103.078
# 2021-10  103.629        104.17  ...         103.659  104.084
# 2021-11  104.335        104.79  ...         104.095  104.781
#
# [119 rows x 48 columns]

# %%
apc_data_2.rename(columns={'지역':'날짜'}, inplace=True)
apc_data_2.head(2)
# Out:
# 지역      서울특별시                ...             동남권
# 규모      40㎡이하 40㎡초과 ~ 60㎡이하  ... 102㎡초과 ~ 135㎡이하   135㎡초과
# 2012-01     -       71.8267  ...         82.7782  90.4809
# 2012-02     -       71.7416  ...         82.0498  89.6516
#
# [2 rows x 48 columns]

# %%
apc_data_2 = apc_data_2.reset_index()

# %%
apc_data_2.rename(columns={'index': '날짜'}, inplace=True)
apc_data_2.drop(columns=['level_0'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:3889: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
apc_data_2
# Out:
# 지역        날짜    서울특별시                ...            동남권
# 규모              40㎡이하 40㎡초과 ~ 60㎡이하  ... 85㎡초과 ~ 102㎡이하 102㎡초과 ~ 135㎡이하   135㎡초과
# 0    2012-01        -       71.8267  ...        76.3143         82.7782  90.4809
# 1    2012-02        -       71.7416  ...        75.8092         82.0498  89.6516
# 2    2012-03        -       71.4696  ...        75.3974         81.4541  89.1133
# 3    2012-04        -       71.1394  ...        75.0875         81.1335  87.9396
# 4    2012-05        -       70.7402  ...        74.6781         80.5968  87.4848
# ..       ...      ...           ...  ...            ...             ...      ...
# 114  2021-07   100.76       101.014  ...        101.287         100.984  100.864
# 115  2021-08  101.771       102.149  ...        102.295         101.872  101.685
# 116  2021-09  102.686       103.198  ...        103.601          102.86  103.078
# 117  2021-10  103.629        104.17  ...        104.295         103.659  104.084
# ...

# %%
apc_data_3 = apc_data_3.set_index(keys=['지역', '규모']).swapaxes(axis1=0, axis2=1)
apc_data_3
# Out:
# 지역         서울특별시                ...             동남권
# 규모         40㎡이하 40㎡초과 ~ 60㎡이하  ... 102㎡초과 ~ 135㎡이하   135㎡초과
# 2012-01        -       68.7632  ...         75.8336   74.306
# 2012-02        -       68.7954  ...         75.6907  74.2384
# 2012-03        -       68.7624  ...         75.3672  74.0559
# 2012-04        -       68.5769  ...         74.6444  73.3727
# 2012-05        -       68.2565  ...         73.8351  73.1246
# ...          ...           ...  ...             ...      ...
# 2021-07  100.244       100.782  ...         101.144  100.968
# 2021-08   100.66       101.719  ...         101.535  101.547
# 2021-09  101.246       102.422  ...         101.935      102
# 2021-10  101.723       102.985  ...         102.568  102.379
# 2021-11  101.873       103.556  ...         103.361  102.617
#
# [119 rows x 48 columns]

# %%
apc_data_4 = apc_data_4.set_index(keys=['지역', '규모']).swapaxes(axis1=0, axis2=1)
apc_data_4
# Out:
# 지역         서울특별시                ...             동남권
# 규모         40㎡이하 40㎡초과 ~ 60㎡이하  ... 102㎡초과 ~ 135㎡이하   135㎡초과
# 2015-06        -       97.3609  ...         99.0522  97.3229
# 2015-07        -        97.375  ...         99.1172  97.3487
# 2015-08        -        97.441  ...         99.2146   97.558
# 2015-09        -        97.665  ...          99.469  97.7122
# 2015-10        -        97.819  ...         99.5143  97.8989
# ...          ...           ...  ...             ...      ...
# 2021-07  100.235       100.224  ...         100.334  100.227
# 2021-08  100.858        100.61  ...         100.452  100.483
# 2021-09  101.048       100.944  ...         101.171  100.935
# 2021-10   101.18       101.228  ...         101.701  101.028
# 2021-11  101.515       101.605  ...         101.793  101.422
#
# [78 rows x 48 columns]
