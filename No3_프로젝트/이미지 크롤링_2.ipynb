# %%
# !pip install git+https://github.com/Joeclinton1/google-images-download.git
# Out:
# ...
#   Cloning https://github.com/Joeclinton1/google-images-download.git to c:\users\rlawk\appdata\local\temp\pip-req-build-u38c1770
#   Resolved https://github.com/Joeclinton1/google-images-download.git to commit ce512d99ff4c5f74a3cfa3bcf83c6a5b05bd873f
# ...
#   Running command git clone -q https://github.com/Joeclinton1/google-images-download.git 'C:\Users\rlawk\AppData\Local\Temp\pip-req-build-u38c1770'

# %%
from google_images_download import google_images_download
response = google_images_download.googleimagesdownload()

arguments = {"keywords":'basenji,scottish deerhound,shetland sheepdog,walker hound,maltese dog,norfolk terrier,african hunting_dog,wire-haired fox terrier,redbone,lakeland terrier,boxer,doberman,otterhound,standard schnauzer,irish water spaniel,black tan coonhound,cairn,affenpinscher,labrador bretriever,ibizan_hound,english setter,weimaraner,giant schnauzer,groenendael',
             "limit":100,"print_urls":True,"format":"jpg"}
paths = response.download(arguments)
print(paths)
# Out:
# Item no.: 1 --> Item name = basenji
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/Basenji_Profile_%28loosercrop%29.jpg/640px-Basenji_Profile_%28loosercrop%29.jpg
# Completed Image ====> 1.640px-basenji_profile_%28loosercrop%29.jpg
# Image URL: https://dogtime.com/assets/uploads/gallery/basenji-dog-breed-pictures/1-standforward.jpg
# Completed Image ====> 2.1-standforward.jpg
# Image URL: https://www.purina.co.uk/sites/default/files/2021-02/BREED%20Hero_0006_basenji_0.jpg
# Completed Image ====> 3.breed%20hero_0006_basenji_0.jpg
# Image URL: https://www.dogtime.com/assets/uploads/2011/01/file_23008_basenji.jpg
# Completed Image ====> 4.file_23008_basenji.jpg
# Image URL: https://www.yourpurebredpuppy.com/dogbreeds/photos-AB/basenjisf3.jpg
# Completed Image ====> 5.basenjisf3.jpg
# Image URL: https://petsfoodnutrition.com/wp-content/uploads/2020/12/Basenji.jpg
# Completed Image ====> 6.basenji.jpg
# ...

# %%
response = google_images_download.googleimagesdownload()

arguments = {"keywords":'redbone dog, cairn terrier',
             "limit":100,"print_urls":True,"format":"jpg"}
paths = response.download(arguments)
print(paths)
# Out:
# Item no.: 1 --> Item name = redbone dog
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/8/8b/Redbone-coonhound-detail.jpg
# Completed Image ====> 1.redbone-coonhound-detail.jpg
# Image URL: https://www.akc.org/wp-content/uploads/2017/11/Redbone-Coonhound.jpg
# Completed Image ====> 2.redbone-coonhound.jpg
# Image URL: https://dogtime.com/assets/uploads/gallery/redbone-coonhound-dog-breed-pictures/layingwhite-9.jpg
# Completed Image ====> 3.layingwhite-9.jpg
# Image URL: https://www.akc.org/wp-content/uploads/2017/11/Redbone-Coonhound-mother-and-puppy.jpg
# Completed Image ====> 4.redbone-coonhound-mother-and-puppy.jpg
# Image URL: https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F47%2F2022%2F01%2F27%2Fredbone-coonhound-with-grey-chest-224765817-2000.jpg
# Completed Image ====> 5.image.jpg
# ...
