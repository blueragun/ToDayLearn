# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rcParams
# !apt-get install fonts-nanum*
rcParams['font.family'] = 'NanumGothicCoding'
rcParams['axes.unicode_minus'] = False
font_manager._rebuild()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file="/content/drive/MyDrive/4조  일반/indeed_job_dataset_ver03.csv"

# %%
datajob=pd.read_csv(file, encoding="utf8")
datajob.head()
# Out:
#    index                                  Job_Title Queried_Salary  ...  m  p  both
# 0      0                             Data Scientist         <80000  ...  1  0     0
# 1      1                             Data Scientist         <80000  ...  0  1     0
# 2      2                             Data Scientist         <80000  ...  0  0     0
# 3      3  Graduate Studies Program - Data Scientist         <80000  ...  0  0     0
# 4      4                           Data Scientist I         <80000  ...  0  0     0
#
# [5 rows x 101 columns]

# %%
test="/content/drive/MyDrive/4조  일반/김장현/2021_data-pro_v03.csv"

# %%
datajob2=pd.read_csv(test, encoding="utf8")
datajob2.head()
# Out:
#    index                  Job_Title Queried_Salary  ...  m  p both
# 0      0             Data Scientist    80000-99999  ...  0  0    1
# 1      1  Healthcare Data Scientist  100000-119999  ...  1  0    0
# 2      2             Data Scientist    80000-99999  ...  1  0    0
# 3      3             Data Scientist    80000-99999  ...  0  0    0
# 4      4             Data Scientist  140000-159999  ...  0  0    0
#
# [5 rows x 96 columns]

# %% [markdown]
# ## 21년 연봉에 따른 석박사

# %% [markdown]
# ### 데이터 사이언스 석사

# %%
SeM = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'Data Scientist')
SmM = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'Data Scientist')
SpM = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'Data Scientist')

# %%
SeM.value_counts()
# Out:
# False    555
# True      44
# dtype: int64

# %%
SmM.value_counts()
# Out:
# False    532
# True      67
# dtype: int64

# %%
SpM.value_counts()
# Out:
# False    575
# True      24
# dtype: int64

# %% [markdown]
# ### 데이터 사이언스 박사

# %%
SeP = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'Data Scientist')
SmP = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'Data Scientist')
SpP = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'Data Scientist')

# %%
SeP.value_counts()
# Out:
# False    582
# True      17
# dtype: int64

# %%
SmP.value_counts()
# Out:
# False    578
# True      21
# dtype: int64

# %%
SpP.value_counts()
# Out:
# False    571
# True      28
# dtype: int64

# %% [markdown]
# ### 데이터 엔지니어 석사

# %%
EeM = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'data engineer')
EmM = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'data engineer')
EpM = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'data engineer')

# %%
EeM.value_counts()
# Out:
# False    579
# True      20
# dtype: int64

# %%
EmM.value_counts()
# Out:
# False    589
# True      10
# dtype: int64

# %%
EpM.value_counts()
# Out:
# False    594
# True       5
# dtype: int64

# %% [markdown]
# ### 데이터 엔지니어 박사

# %%
EeP = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'data engineer')
EmP = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'data engineer')
EpP = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'data engineer')

# %%
EeP.value_counts()
# Out:
# False    598
# True       1
# dtype: int64

# %%
EmP.value_counts()
# Out:
# False    599
# dtype: int64

# %%
EpP.value_counts()
# Out:
# False    598
# True       1
# dtype: int64

# %% [markdown]
# ### 데이터 분석가 석/박사

# %%
AeM = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'Data Analyst')
AmM = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'Data Analyst')
ApM = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Degree == 'M') & (datajob2.Job_Type == 'Data Analyst')

# %%
AeM.value_counts()
# Out:
# False    570
# True      29
# dtype: int64

# %%
AmM.value_counts()
# Out:
# False    595
# True       4
# dtype: int64

# %%
ApM.value_counts()
# Out:
# False    599
# dtype: int64

# %%
AeP = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'Data Analyst')
AmP = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'Data Analyst')
ApP = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Degree == 'P') & (datajob2.Job_Type == 'Data Analyst')

# %%
AeP.value_counts()
# Out:
# False    599
# dtype: int64

# %%
AmP.value_counts()
# Out:
# False    599
# dtype: int64

# %%
ApP.value_counts()
# Out:
# False    599
# dtype: int64

# %%
Se = ((datajob2.Avg_Salary == '<80000') | (datajob2.Avg_Salary =='80000-99999')) & (datajob2.Job_Type == 'Data Scientist')
Sm = ((datajob2.Avg_Salary == '100000-119999') | (datajob2.Avg_Salary =='120000-139999')) & (datajob2.Job_Type == 'Data Scientist')
Sp = ((datajob2.Avg_Salary == '140000-159999') | (datajob2.Avg_Salary =='>160000')) & (datajob2.Job_Type == 'Data Scientist')

# %%
Se.value_counts()
# Out:
# False    468
# True     131
# dtype: int64

# %%
Sm.value_counts()
# Out:
# False    456
# True     143
# dtype: int64

# %%
Sp.value_counts()
# Out:
# False    507
# True      92
# dtype: int64

# %%
Se1 = (datajob2.Avg_Salary == '<80000') & (datajob2.Job_Type == 'Data Scientist')
Se2 = (datajob2.Avg_Salary =='80000-99999') & (datajob2.Job_Type == 'Data Scientist')
Sm1 = (datajob2.Avg_Salary == '100000-119999') & (datajob2.Job_Type == 'Data Scientist')
Sm2 = (datajob2.Avg_Salary =='120000-139999') & (datajob2.Job_Type == 'Data Scientist')
Sp1 = (datajob2.Avg_Salary == '140000-159999') & (datajob2.Job_Type == 'Data Scientist')
Sp2 = (datajob2.Avg_Salary =='>160000') & (datajob2.Job_Type == 'Data Scientist')

# %%
Se1.value_counts()
# Out:
# False    548
# True      51
# dtype: int64

# %%
Se2.value_counts()
# Out:
# False    519
# True      80
# dtype: int64

# %%
Sm1.value_counts()
# Out:
# False    516
# True      83
# dtype: int64

# %%
Sm2.value_counts()
# Out:
# False    539
# True      60
# dtype: int64

# %%
Sp1.value_counts()
# Out:
# False    550
# True      49
# dtype: int64

# %%
Sp2.value_counts()
# Out:
# False    556
# True      43
# dtype: int64

# %%
Ee1 = (datajob2.Avg_Salary == '<80000') & (datajob2.Job_Type == 'data engineer')
Ee2 = (datajob2.Avg_Salary =='80000-99999') & (datajob2.Job_Type == 'data engineer')
Em1 = (datajob2.Avg_Salary == '100000-119999') & (datajob2.Job_Type == 'data engineer')
Em2 = (datajob2.Avg_Salary =='120000-139999') & (datajob2.Job_Type == 'data engineer')
Ep1 = (datajob2.Avg_Salary == '140000-159999') & (datajob2.Job_Type == 'data engineer')
Ep2 = (datajob2.Avg_Salary =='>160000') & (datajob2.Job_Type == 'data engineer')

# %%
Ee1.value_counts()
# Out:
# False    582
# True      17
# dtype: int64

# %%
Ee2.value_counts()
# Out:
# False    557
# True      42
# dtype: int64

# %%
Em1.value_counts()
# Out:
# False    564
# True      35
# dtype: int64

# %%
Em2.value_counts()
# Out:
# False    587
# True      12
# dtype: int64

# %%
Ep1.value_counts()
# Out:
# False    593
# True       6
# dtype: int64

# %%
Ep2.value_counts()
# Out:
# False    592
# True       7
# dtype: int64

# %%
Ae1 = (datajob2.Avg_Salary == '<80000') & (datajob2.Job_Type == 'Data Analyst')
Ae2 = (datajob2.Avg_Salary =='80000-99999') & (datajob2.Job_Type == 'Data Analyst')
Am1 = (datajob2.Avg_Salary == '100000-119999') & (datajob2.Job_Type == 'Data Analyst')
Am2 = (datajob2.Avg_Salary =='120000-139999') & (datajob2.Job_Type == 'Data Analyst')
Ap1 = (datajob2.Avg_Salary == '140000-159999') & (datajob2.Job_Type == 'Data Analyst')
Ap2 = (datajob2.Avg_Salary =='>160000') & (datajob2.Job_Type == 'Data Analyst')

# %%
Ae1.value_counts()
# Out:
# False    507
# True      92
# dtype: int64

# %%
Ae2.value_counts()
# Out:
# False    589
# True      10
# dtype: int64

# %%
Am1.value_counts()
# Out:
# False    593
# True       6
# dtype: int64

# %%
Am2.value_counts()
# Out:
# False    594
# True       5
# dtype: int64

# %%
Ap1.value_counts()
# Out:
# False    599
# dtype: int64

# %%
Ap2.value_counts()
# Out:
# False    598
# True       1
# dtype: int64

# %% [markdown]
# # 18년 데이터 검열

# %%
Ee1 = (datajob.Queried_Salary == '<80000') & (datajob.Job_Type == 'data_engineer')
Ee2 = (datajob.Queried_Salary =='80000-99999') & (datajob.Job_Type == 'data_engineer')
Em1 = (datajob.Queried_Salary == '100000-119999') & (datajob.Job_Type == 'data_engineer')
Em2 = (datajob.Queried_Salary =='120000-139999') & (datajob.Job_Type == 'data_engineer')
Ep1 = (datajob.Queried_Salary == '140000-159999') & (datajob.Job_Type == 'data_engineer')
Ep2 = (datajob.Queried_Salary =='>160000') & (datajob.Job_Type == 'data_engineer')

# %%
Ee1.value_counts()
# Out:
# False    5688
# True       27
# dtype: int64

# %%
Ee2.value_counts()
# Out:
# False    5590
# True      125
# dtype: int64

# %%
Em1.value_counts()
# Out:
# False    5319
# True      396
# dtype: int64

# %%
Em2.value_counts()
# Out:
# False    5263
# True      452
# dtype: int64

# %%
Ep1.value_counts()
# Out:
# False    5440
# True      275
# dtype: int64

# %%
Ep2.value_counts()
# Out:
# False    5611
# True      104
# dtype: int64

# %%
Se1 = (datajob.Queried_Salary == '<80000') & (datajob.Job_Type == 'data_scientist')
Se2 = (datajob.Queried_Salary =='80000-99999') & (datajob.Job_Type == 'data_scientist')
Sm1 = (datajob.Queried_Salary == '100000-119999') & (datajob.Job_Type == 'data_scientist')
Sm2 = (datajob.Queried_Salary =='120000-139999') & (datajob.Job_Type == 'data_scientist')
Sp1 = (datajob.Queried_Salary == '140000-159999') & (datajob.Job_Type == 'data_scientist')
Sp2 = (datajob.Queried_Salary =='>160000') & (datajob.Job_Type == 'data_scientist')

# %%
Se1.value_counts()
# Out:
# False    5667
# True       48
# dtype: int64

# %%
Se2.value_counts()
# Out:
# False    5482
# True      233
# dtype: int64

# %%
Sm1.value_counts()
# Out:
# False    5005
# True      710
# dtype: int64

# %%
Sm2.value_counts()
# Out:
# False    4945
# True      770
# dtype: int64

# %%
Sp1.value_counts()
# Out:
# False    5164
# True      551
# dtype: int64

# %%
Sp2.value_counts()
# Out:
# False    5484
# True      231
# dtype: int64

# %%
Ae1 = (datajob.Queried_Salary == '<80000') & (datajob.Job_Type == 'data_analyst')
Ae2 = (datajob.Queried_Salary =='80000-99999') & (datajob.Job_Type == 'data_analyst')
Am1 = (datajob.Queried_Salary == '100000-119999') & (datajob.Job_Type == 'data_analyst')
Am2 = (datajob.Queried_Salary =='120000-139999') & (datajob.Job_Type == 'data_analyst')
Ap1 = (datajob.Queried_Salary == '140000-159999') & (datajob.Job_Type == 'data_analyst')
Ap2 = (datajob.Queried_Salary =='>160000') & (datajob.Job_Type == 'data_analyst')

# %%
Ae1.value_counts()
# Out:
# False    5002
# True      713
# dtype: int64

# %%
Ae2.value_counts()
# Out:
# False    5120
# True      595
# dtype: int64

# %%
Am1.value_counts()
# Out:
# False    5427
# True      288
# dtype: int64

# %%
Am2.value_counts()
# Out:
# False    5645
# True       70
# dtype: int64

# %%
Ap1.value_counts()
# Out:
# False    5668
# True       47
# dtype: int64

# %%
Ap2.value_counts()
# Out:
# False    5635
# True       80
# dtype: int64
