# %% [markdown]
# # 객체지향 프로그래밍
# - oop(object oriented programming)
# - 객체지향은 개발 방법론입니다.
#   - 소프트웨어를 관리하고 개발하는 전체 과정에 대한 얘기
#   - 객체지향은 하나의 개념
#   - 소프트웨어 공학
#     * 기획 - 요구사항 - 설계 - 구현 - 배포 - 유지보수 순
#     * 개발적인 부분에서 언어들이 객체지향 프로그래밍을 위해서 제공하는 기능
#     * 수업에서 다루는 클래스나 객체에 대한 내용은 아주 일부분
#     * 수업에서는 정확한 이해는 어려움
#   - 파이썬에서 제공하는 클래스와 객체에 대해 배운다
#     * 클래스와 객체라는 건, 파이썬에서만 사용할 수 있는 기술 아님
#     * 파이썬은 완벽한 객체지향 언어 아님
#       - 느슨하게 객체지향 문법 제공

# %% [markdown]
# # 클래스
#   - 클래스를 아주아주 축소한 개념에서는
#     * 사용자가 정의하는 **새로운 타입 정도**호 해석
#     * int, float, bool, str, list, tuple, range,... -> 파이썬에서 미리 정의해둔 클래스들 임
#     * 이렇게 미리 정의된 클래스 외에도 사용자가 직접 타입을 정의할 수 있음
#       - 새로운 클래스를 만들어서 사용할 수 있음
#
#   - 클래스를 정의하는 기본형태
#
#   ```
#   class 클래스 이름 :
#   [들여쓰기] 클래스 블록....
#   ```
#
# - 클래스를 정의할 때 고려해야 되는 규칙
#   * 클래스의 이름은 대문자로 시작(권장)
#   * 소문자로 시작하는 경우는 변수이름과, 함수이름
#     - 결국, 변수나 함수와 구분하기 위해서 권장
#     - int, float, list...  와 같이 잘알려져 있는 파이썬의 기본 클래스들은 구분이 가능하기 때문에 소문자로 표현

# %% [markdown]
# # 객체
#   - object 또는 instance라고 한다
#   - 변수의 확장된 형태
#     * 파이썬은 전부 객체
#     * 심지어 클래스도 하나의 객체로써 다뤄지긴 함
#   - 클래스의 정의
#     * 이렇게 정의된 클래스를 사용하기 위해서는 메모리에 만들어야 함
#     * 정의된 클래스를 메모리에 만들면 객체라 함
#     * 함수와 동일한 개념
#       - 함수를 정의하고 함수를 호출하면 실행(메모리를 생성)
#       - 클래스를 정의하고 클래스에 대한 메모리를 생성(객체)
#         * 클래스를 호출하는 것으로 객체를 생성할 수 있음
#         * 함수는 실행이 끝나면 메모리를 반환하고 종료되지만,
#         * 객체는 종료되지 않는다. 한번 메모리에 만들어지면 임의로 삭제하기 전까지는 계속 남아있음
#
#   - 파이썬은 사실 모든 것이 '객체'
#     - 우리가 배웠던 모든 것이 객체
#     - 함수도 객체, 변수도 객체

# %%
# 수업시간에는 사람이라는 클래스를 정의
# 객체는 살아있는 생물이나, 물건처럼 취급
# 사람을 모델로 해서 클래스를 정의하는 방법을 설명

class Person :
  pass # 파이썬은 클래스도 빈 블록을 허용 안함

# %%
Person()
# 객체 호출 / 대분자로 함으로써 Person이 객체라는 것은 인식할 수 있음

# %%
# 위와 같은 방식으로는 객체를 사용할 수 없다
# 위치는 확인이 가능하나 접근(참조)가 안된다
# 변수가 반드시 필요
obj = Person()
obj

# %% [markdown]
# # 변수를 통한 객체의 참조
#   - 일반적으로 객체지향 프로그래밍에서는 변수를 하나의 객체로 동일하게 취급
#   - 정확하게는 변수와 객체는 구분이 가능하지만
#   - 변수를 객체와 동일시 하게 됨
#   - 변수 자체를 하나의 객체로 취급

# %%
장동건 = Person()
원빈 = Person()

print(장동건)
print(원빈)

# %%
# 다른 메모리로 복사하게 되면 주소가 복사된다
# 얕은 복사

고소영 = 장동건

print(고소영)
print(장동건)

# %% [markdown]
# # 클래스의 구조
# - 속성과 기능으로 정의
#   - 클래스 내부에서 정의되는 '변수'를 클래스의 '속성'
#   - 클래스 내부에서 정의되는 '함수'를 클래스의 '기능'
#   - 한 클래스는 여러개의 속성과 기능으로 정의
#     - 이때, 속성과 기능은 클래스의 특징을 반영
#     - Person 클래스는 어떤 특징을 반영?
#       - 사람이라면 누구나 가지고 있는 특성: 이름, 나이, 사는 곳
#       - 사람이라면 누구나 가지고 있는 기능: 먹고, 마시고, 자고
#
#     - 리스트 클래스는 어떤 특징
#       - 속성: 리스트의 원소
#       - 기능: append, extend, insert, reverse...
#     - 클래스 내에서 정의된 함수를 '메소드'라고 표현
#       - 표현을 다르게 할 뿐이고, 동작을 동일
#       - 클래스 내부에서 정의된 경우와 그렇지 않은 경우를 구분해서 표현
#
#     - 변수
#       - 전역, 지역, 클래스 변수, 객체 변수
#         - 클래스 변수는 클래스 내에서 정의되는 변수
#         - 객체 변수는 객체 내에서 정의되는 변수

# %% [markdown]
# # 객체 변수
#   - 객체가 없으면 정의할 수 없음
#     - 객체가 생성된 이후 정의 가능
#   - 동일 타입이라고 해도, 객체와 객체 간에는 객체변수를 서로 공유하지 않음
#     - 객체 고유의 변수
#     - 함수의 고유 메모리에 생성되는 변수를 지역변수
#     - 객체의 고유 메모리에 생성되는 변수를 객체변수

# %%
# 1. 객체가 먼저 생성되어야 함
장동건 = Person()

# %%
# 2. 만들어진 객체를 통해서 변수를 정의
장동건.name = '장동건'
장동건.age = 20

# %%
# 객체를 통해서 정의된 객체변수를 참조
print(장동건.name)
print(장동건.age)
# Out:
# 장동건
# 20

# %%
# 객체 간에 객체변수는 서로 공유되지 않음
원빈 = Person()

원빈.name = '원빈'
원빈.age = 30

print(원빈.name)
print(원빈.age)
# Out:
# 원빈
# 30

# %%
print(장동건.name)
print(원빈.age)
# Out:
# 장동건
# 30

# %%
print(장동건.name)
print(원빈.name)
# Out:
# 장동건
# 원빈

# %% [markdown]
# # 파이썬에서 '.'의 의미
#   - 네임스페이스의 역할
#   - 참조하려는 변수, 함수 또는 클래스가 어디에 정의되어 있는지를 표현
#     - 변수를 예로 들면, 변수가 객체 내에서 정의된 변수일 수도 있고,
#     - 클래스에서 정의된 변수, 혹은 다른 파이썬 소스파일에서 정의된 변수
#       - 이름이 같으면 충돌이 발생(구분할 수 없게 됨)
#
#   - 어디에 쓰였다는 것을 명확하게 하기위한 것
#
#   - 1. 객체.변수 = 객체의 멤버
#   - 2. 클래스.변수
#   - 3. 모듈.변수

# %%
list.append()

# %% [markdown]
# # 클래스.변수(공유 변수)
#   - 객체와는 무관한 변수
#     - 객체 없이도 참조 가능한 변수
#   -클래스 내부, 메소느 외부에 정의가 되면 클래스 변수가 된다
#   - 공유변수
#     - 모든 객체가 하나의 동일한 클래스 변수를 참조

# %%
class Person  :
  nation = 'korea'
  # 한국 국적을 가지고 있는 사람을 가정

# %%
# 객체와 상관없이 클래스를 통해서 참조
Person.nation
# Out:
# 'korea'

# %% [markdown]
# **주의!**
# - 파이썬은 객체를 통해서 클래스 변수에 대한 참조가 가능
#   - 사실 이런 접근은 막아야 하지만, 파이썬은 허용
#   - 대부분의 언어는 이런 접근을 사전 차단함
#   - 때문에 파이썬은 문제가 발생할 수 있음
#
# - 클래스 변수는 클래스를 통해서만 접근!하도록 할 것

# %%
장동건 = Person()

print( 장동건.nation)

# 이게되네?
# 원래는 되면 안되는데....
# 코드 자체가 모호해지는 문제(객체변수인지???, 클래스변수인지... )
# Out:
# korea

# %%
# 이건 클래스 변수인가?? 객체 변수 인가??
장동건.nation = 'German'
print( 장동건.nation)
# Out:
# German

# %%
# 위는 객체 변수 임... 왜냐 하면
print( Person.nation)
# Out:
# korea

# %%
# 위와 같이 클래스의 변수는 그대로이기 때문이다.

# %% [markdown]
# # 메소드
#   - 그냥 함수
#   - 클래스 내에서 정의된 함수와 구분하기 위해서 다르게 부름
#   - 함수의 특징은 동일함

# %%
class Person :
  nation = 'korea'

  # 클래스 내에서 정의되는 함수를 메소드
  # 메소드의 첫번째 파라미터는 무조건 self가 됨
  def method(self):
    print('함수는 동일함')
    print('클래스 내에서 정의되었을 뿐')
    print('self is: ', self)
    print('name is:', self.name)

# %%
# 메소드는 객체를 통해서만 호출 가능
장동건 = Person()
장동건.name = '장동건'
장동건.method() # self는 직접 전달하지 않는다

# self에 대한 입력을 넣어준적이 없는데 나옴
# Out:
# 함수는 동일함
# 클래스 내에서 정의되었을 뿐
# self is:  <__main__.Person object at 0x7f5f51dbdb90>
# name is: 장동건

# %% [markdown]
# #self
#   - 여러 다른 책이나 강의를 보면, 객체 자기자신을 의미한다고 설명을 많이 하게되는데 이게 뭔말???
#
#   - 함수의

# %%
장동건

# %%
원빈.method()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-106b8fbf59a2> in <module>()
# ----> 1 원빈.method()
#
# AttributeError: 'Person' object has no attribute 'method'

# %%
원빈 = Person()
원빈.name = '원빈'
원빈.method()
# Out:
# 함수는 동일함
# 클래스 내에서 정의되었을 뿐
# self is:  <__main__.Person object at 0x7f5f51dc9210>
# name is: 원빈

# %%
원빈

# %% [markdown]
# # 같은 표현
#   - 장동건.속성, self.속성은 같은 표현이 됨
#     - 장동건 객체를 통해서 속성(변수)에 대한 참조와
#     - 메소드 내에서 self를 통해서 속성(변수)에 대한 참조를 하는 것은 같다

# %% [markdown]
# # self 이외의 파라미터가 있다면/
# - self를 제외한 나머지 파라미터는 입력값을 전달

# %%
class Person:
  nation = 'korea'

  def method(self, a, b):
    return a + b

# %%
장동건 = Person()
장동건.method(10,20)  # self를 제외한 나머지 입력값만 전달
# Out:
# 30

# %% [markdown]
# ###특별한 메소드들###
# - 매직 메소드
#   - 특별한 의미를 가지고 있는 미리 정의된 메소드들이 있다
#   - 메소드 이름 앞과 뒤에 '__'(더블 언더바, 더블 언더스코어, 던더)가 붙어 있는 메소드
#   - 던더 메소드라 부른다

# %%
class Person:
  pass

# %%
dir(Person)  # dir 명령을 통해서 클래스에 정의된 매직 메소드를 확인할 수 있다
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# ### 생성자
# - 생성 메소드 정도로 이래(Constructor)
#   - `__init__`
#   - 객체가 생성될 떄, 인터프리터에 의해 자동으로 호출되는 메소드
#
# - 객체의 초기화
#   - 객체가 생성될떄, 모든 객체가 동일한 속성을 가지게 하고 싶다면?
#   - Person 타입의 객체들은 모두 'name'이라는 속성을 가져야 한다.
#   - 객체변수는 미리 정의할 수 없다
#   - 객체가 생성된 이후에 정의 가능
#   - 생성자는 언제 실행?
#     - 객체가 실행될 때
#     - 즉, 생성자가 실행이 되었다는 것은 객체가 만들어졌음을 의미
#     - 생성자를 통해서 객체변수에 대한 초기화를 해볼 수 있음

# %%
class Person:
  nation  = 'korea'

  def __init__(self):
    print('call __init__')

  def method(self, a, b):
    return a + b

# %%
장동건 = Person()
# Out:
# call __init__

# %%
class Person:
  nation  = 'korea'

  def __init__(self, name, age):
    self.name = name
    self.age = age

  def method(self, name, age):
    return name + age

장동건 = Person('장동건', 20)
원빈 = Person('원빈', 30)

# %%
장동건 = Person()
원빈 = Person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-d660ce7e9e13> in <module>()
# ----> 1 장동건 = Person()
#       2 원빈 = Person()
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'age'

# %% [markdown]
# ### 연산자

# %%
class Person:
  nation  = 'korea'

  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __add__(self, obj):
    print('덧셈처럼 보이지만, 메소드 호출')
    return (self.name + obj.name, self.age + obj.age)

  def method(self, a, b):
    return a + b

장동건 = Person('장동건', 20)
원빈 = Person('원빈', 30)

print( 장동건 + 원빈 )
# Out:
# 덧셈처럼 보이지만, 메소드 호출
# ('장동건원빈', 50)

# %% [markdown]
# ## 함수
# - 파이썬에서는 함수도 객체
#   - function 클래스로 만들어진 객체
#   - function 클래스의 객체는 () 를 붙여서 호출하게 되는데
#   - 이것도 매직 메소드의 하나

# %%
class UserFunction:

  # 기본적으로는 __call__ 매직 메소드가 구현된 클래스의 객체가 함수가 된다
  def __call__(self):
    print('함수가 호출되었습니다.')

# %%
function = UserFunction()

# %%
function()
# Out:
# 함수가 호출되었습니다.

# %% [markdown]
# ### Static Method VS Class Method
# - 객체와 상관없이 참조 가능한 변수(클래스 변수)
# - 객체와 상관없이 참조 가능한 메소드
#   - 클래스 변수는 객체와 상관없이 참조 가능
#   - 메소드는 객체를 통해서만 호출이 가능
#     - 메소드를 통해서 클래스 변수를 참조하려면 반드시 객체가 필요한 이상상황 발생
#   - 객체가 아닌, 클래스를 통해서 호출할 수 있다

# %%
class Person:
  nation  = 'korea'

  # static method
  # 데코레이터를 통해서 메소드를 정의
  # 스태틱 메소드로 정의하고 싶은 메소드 앞에 데코레이터를 붙여주면 됨
  # 스태틱 메소드는 self 파라미터를 정의하지 않음(클래스를 통해 접근)
 
  @staticmethod #데코레이터
  def staticMethod():
    return Person.nation
  
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def method(self, a, b):
    return a + b

# %%
Person.staticMethod()
# Out:
# 'korea'

# %%
class Person:
  nation  = 'korea'

  # class method 역시 데코레이터를 통해서 정의
  # 첫 번째 파라미터로 'cls'를 정의함
  # 객체를 구분하는 self와 동일한 역할을 하는 cls가 존재
  # 클래스 메소드는 cls를 파라미터를 통해서 클래스 구분
  
  @staticmethod #데코레이터
  def staticMethod():
    return Person.nation

  @classmethod #데코레이터
  def classMethod(cls):
    return cls.nation
  
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def method(self, a, b):
    return a + b

# %%
# 두 메소드 모두 클래스를 통해서 호출
# 지금은 두 메소드의 차이점을 확인하기 어렵고, 뒤에서 상속이라는 개념을 통해서 차이점을 확인
print( Person.staticMethod())
print( Person.classMethod())
# Out:
# korea
# korea
