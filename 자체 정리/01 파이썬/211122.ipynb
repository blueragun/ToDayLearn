# %%
print("Hello python")
print("Hello python")
# Out:
# Hello python
# Hello python

# %%
type(.)
# Out:
#   File "<ipython-input-2-be29e4431175>", line 1
#     type(.)
#          ^
# SyntaxError: invalid syntax

# %%
type(.10)
# Out:
# float

# %%
type(10.)
# Out:
# float

# %%
true + true + true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bb7a759d5c7d> in <module>()
# ----> 1 true + true + true
#
# NameError: name 'true' is not defined

# %%
True + True + True
# Out:
# 3

# %%
"""Hello
Python"""
# Out:
# 'Hello\nPython'

# %%
'hello \
Python'
# Out:
# 'hello Python'
