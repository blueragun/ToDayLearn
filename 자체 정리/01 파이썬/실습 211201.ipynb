# %% [markdown]
# # 알고리즘 문지 풀이
# - 기초적인 코딩 과정을 익히기 위함
# - 핵심 : 제어문(반복문), 리스트
# - 가장 배우기 어렵고, 힘든 과정
#
#
# - 실습사이트
#   - 백준 : 알고리즘 경진대회 준비
#     - 난이도 별로 다양하게 문제들이 준비
#     - 초보자부터 숙련자까지 전부 사용해볼 수 있음
#
#   - 코드업 : 학생들을 위한 사이트
#     - 초보자를 위한 문제들이 다수
#
#   - 프로그래머스
#     - 코딩테스트를 위한 사이트
#     - 기업용 기출문제들이 있음
#
#   - leetcode
#     - 해외취업자들이 활용하면 좋음
#     - 단점 : 부분 유료화
#     - 해외에서는 이 사이트에서 채용도 이루어짐
#
#   - topcoder
#     - 전통적으로 아주 유명한 프로그래밍 경진대회 사이트
#     - 릿코드와 마찬가지로 채용도 활발하게 이루어짐

# %%
strs = 'computer science'

# %%
print(strs, strs, strs)
# Out:
# computer science computer science computer science

# %%
a, b = int(), input().split()
